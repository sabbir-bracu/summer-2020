# %%
#import spacy
#spacy.cli.download("en_core_web_sm")

# %%
LABEL = "model"

# %%
import spacy

nlp=spacy.blank("en")

nlp.add_pipe(nlp.create_pipe('ner'))

nlp.begin_training(g=0)

# %%
nlp=spacy.load('en_core_web_sm')

# %%
ner=nlp.get_pipe("ner")

# %%
LABEL = 'model'
TRAIN_DATA = [('iphone 10 pro 64MP/108MP??', {'entities': [(0, 9, 'model')]}), ('Poco X3 pro official ki international??', {'entities': [(0, 7, 'model')]}), ('redmi 10 pro max, sathe kono gift ache?', {'entities': [(0, 7, 'model')]}), ('Poco x3 Indian version ta ki ase... ??', {'entities': [(0, 7, 'model')]}), ('redmi Note 10 pro 8/128 gb available nai?', {'entities': [(0, 11, 'model')]}), ('Vai redmi Note 10 lite available...??', {'entities': [(4, 15, 'model')]}), ('poco m2 pro 6/128 available?', {'entities': [(0, 11, 'model')]}), ('redmi Note 10 6/128 international hobe ki??', {'entities': [(0, 11, 'model')]}), ('Oneplus 8 dual sim nai?', {'entities': [(0, 9, 'model')]}), ('redmi k40 price', {'entities': [(0, 9, 'model')]}), ('redmi k40 kobe asbe?', {'entities': [(0, 9, 'model')]}), ('redmi Note 10 pro max cn hobe?', {'entities': [(0, 11, 'model')]}), ('Poco f3 ni?', {'entities': [(0, 7, 'model')]}), ('poco x3 Ata ki made by India.....', {'entities': [(0, 7, 'model')]}), ('redmi Note 10 4/64', {'entities': [(0, 11, 'model')]}), ('waiting for iphone 12 pro max', {'entities': [(12, 21, 'model')]}), ('Poco x3 pro int. Global available? Price?', {'entities': [(0, 7, 'model')]}), ('R u bringing 4g or 5g iphone 12?', {'entities': [(22, 31, 'model')]}), ('Redmi note 9 pro max prise koto..', {'entities': [(0, 11, 'model')]}), ('poco x3 Price??', {'entities': [(0, 7, 'model')]}), ('poco x3 ind (6/128gb) unofficial available??', {'entities': [(0, 7, 'model')]}), ('redmi Note 10 s কবে আসবে?', {'entities': [(0, 11, 'model')]}), ('iphone 11 er price koto', {'entities': [(0, 9, 'model')]}), ('redmi k40 kbe asbe?', {'entities': [(0, 9, 'model')]}), ('Price of iphone 11 pro ?', {'entities': [(9, 18, 'model')]}), ('Mi 11 lite 5g unofficial available?', {'entities': [(0, 10, 'model')]}), ('Mi 11 pro??', {'entities': [(0, 9, 'model')]}), ('Poco M2 /Redmi Note 9 inter ache?', {'entities': [(9, 20, 'model')]}), ('redmi Note 9 pro max 6/64.', {'entities': [(0, 11, 'model')]}), ('Mi 11 lite 6/64 price koto', {'entities': [(0, 10, 'model')]}), ('Apple iphone 12 product price?', {'entities': [(6, 15, 'model')]}), ('EMI facility for iphone 12 pro max ?', {'entities': [(17, 26, 'model')]}), ('konta niba? Iphone 12 naki poco x3 ?', {'entities': [(27, 34, 'model')]}), ('Poco m3 6/128 available achey??', {'entities': [(0, 7, 'model')]}), ('M2 pro Or Realme 8', {'entities': [(10, 18, 'model')]}), ('Poco x3 pro 6/128 =24500 ata ki official na ki unofficial', {'entities': [(0, 7, 'model')]}), ('Poco f3 dam ki 31..32...as ba', {'entities': [(0, 7, 'model')]}), ('oneplus 8t (12/256) Silver colour available ache?', {'entities': [(0, 9, 'model')]}), ('poco x3 pro (8/128) available ache', {'entities': [(0, 7, 'model')]}), ('redmi Note 10 ki official-?', {'entities': [(0, 11, 'model')]}), ('redmi k40 ace', {'entities': [(0, 9, 'model')]}), ('redmi Note 10 pro mex 6/128 gb 108 mp official koto?', {'entities': [(0, 11, 'model')]}), ('Redmi 9 power  কত', {'entities': [(0, 7, 'model')]}), ('redmi k40 available?', {'entities': [(0, 9, 'model')]}), ('redmi Note 10 (4/64) er official price ki?', {'entities': [(0, 11, 'model')]}), ('redmi k40', {'entities': [(0, 9, 'model')]}), ('Realme c3 4/64 hobe?', {'entities': [(0, 9, 'model')]}), ('redmi Note 10 pro offical dam dicout diya 26 k eta un official 24500 chai vai apnera,ki pagol hoiya gasen naki', {'entities': [(0, 11, 'model')]}), ('oneplus 9 pro 12/256 ki global edition?', {'entities': [(0, 9, 'model')]}), ('redmi Note 10 pro 6/128gb which country rom?', {'entities': [(0, 11, 'model')]}), ('poco x3 6/128 unofficial nai', {'entities': [(0, 7, 'model')]}), ('Poco m3 6/128 available??', {'entities': [(0, 7, 'model')]}), ('oneplus 8t 8-128 price ?', {'entities': [(0, 9, 'model')]}), ('Vai redmi Note 10 pro ase???', {'entities': [(4, 15, 'model')]}), ('redmi Note 10 pro max price', {'entities': [(0, 11, 'model')]}), ('redmi Note 10 6/128 need.....koto?', {'entities': [(0, 11, 'model')]}), ('redmi Note 10 s?', {'entities': [(0, 11, 'model')]}), ('Vhaia redmi note 8 koto tk??', {'entities': [(6, 17, 'model')]}), ('redmi Note 10 pro Indian price koto??', {'entities': [(0, 11, 'model')]}), ('Poco x3 pro 6/128 price ?', {'entities': [(0, 7, 'model')]}), ('poco x3 6/128 indian unofficial price ??', {'entities': [(0, 7, 'model')]}), ('I need it for Redmi K20', {'entities': [(14, 23, 'model')]}), ('redmi k40 Bruce Lee special edition mybe', {'entities': [(0, 9, 'model')]}), ('nope, waiting for mi 11 lite 5g', {'entities': [(18, 28, 'model')]}), ('Poco x3 indian price koto?', {'entities': [(0, 7, 'model')]}), ('এইটা POCO x3 pro এর জন্য পাওয়া যাবে?', {'entities': [(5, 12, 'model')]}), ('Mi 11 lite 5G kobe anben', {'entities': [(0, 10, 'model')]}), ('Er theke oneplus 9R far better', {'entities': [(9, 18, 'model')]}), ('iphone 7 plus er nai emon', {'entities': [(0, 13, 'model')]}), ('Mi 11 lite ki Bangladesh a official asbe..', {'entities': [(0, 10, 'model')]}), ('Poco f3 available', {'entities': [(0, 7, 'model')]}), ('xiaomi redmi mi 11 lite 5g available?', {'entities': [(13, 23, 'model')]}), ('Redmi note 9 nibo', {'entities': [(0, 11, 'model')]}), ('poco x3 pro ki international global?', {'entities': [(0, 7, 'model')]}), ('redmi k40 8-128 white ki available', {'entities': [(0, 9, 'model')]}), ('redmi Note 10 pro(indian) price ?', {'entities': [(0, 11, 'model')]}), ('Mi 11 lite 5g ( SD 780g) :', {'entities': [(0, 10, 'model')]}), ('redmi Note 10 pro nibo 6/128', {'entities': [(0, 11, 'model')]}), ('Exchange kora jane realme 8 pro exchange kore mi 11 lite Nita cacci', {'entities': [(19, 27, 'model')]}), ('redmi Note 10 official price?', {'entities': [(0, 11, 'model')]}), ('Mi 11 lite price?', {'entities': [(0, 10, 'model')]}), ('poco x3 pro indian naki international?', {'entities': [(0, 7, 'model')]}), ('Realme 8 ,20000 hobe v', {'entities': [(0, 8, 'model')]}), ('Redmi note 9 nibo....', {'entities': [(0, 11, 'model')]}), ('poco x3 pro 8/128 ?', {'entities': [(0, 7, 'model')]}), ('REDMI NOTE 9 pro', {'entities': [(0, 11, 'model')]}), ('Okay! Poco x3 pro & very sleek design okay again', {'entities': [(6, 13, 'model')]}), ('Poco x3 pro indian version and chineese version er difference ki? and better konta?', {'entities': [(0, 7, 'model')]}), ('redmi k40 8/256 price koto?', {'entities': [(0, 9, 'model')]}), ('এতদিন ধরে Poco X3 চালাচ্ছি কিন্ত ফোনটা এত যে প্রিটি ভিডিওটি না দেখলে জীবনেও জানতাম না।', {'entities': [(10, 17, 'model')]}), ('X3 pro slick hoile vivo v20 is a joke', {'entities': [(19, 27, 'model')]}), ('redmi k40 white ki available', {'entities': [(0, 9, 'model')]}), ('Ei video dekhar por.Poco X3 kinar iccha chole geche', {'entities': [(20, 27, 'model')]}), ('redmi Note 10  official  4/64 ki available??', {'entities': [(0, 11, 'model')]}), ('redmi Note 10 pro indian tar', {'entities': [(0, 11, 'model')]}), ('redmi Note 10 pro max price? ?', {'entities': [(0, 11, 'model')]}), ('vai redmi k30i 5g er ki ekno kuno somadan ase nai', {'entities': [(4, 13, 'model')]}), ('vai redmi Note 10 pro offer dilen na?', {'entities': [(4, 15, 'model')]}), ('POCO X3 Pro এর অফার থাকলে বইলেন, এইসব লুতুপুতু খেলা দেখায়েন নাহ।', {'entities': [(0, 7, 'model')]}), ('Global Oneplus 8 pro 12/256GB & 8/128 GB প্রাইজ কত ভাই...?', {'entities': [(7, 16, 'model')]}), ('oneplus nord price??', {'entities': [(0, 12, 'model')]}), ('redmi Note 10 price koto', {'entities': [(0, 11, 'model')]}), ('oneplus nord er version valo na', {'entities': [(0, 12, 'model')]}), ('Redmi note 9 t 5G ki available hobe', {'entities': [(0, 11, 'model')]}), ('redmi Note 10 pro r offer den ekta boro soro..', {'entities': [(0, 11, 'model')]}), ('poco f3 available and price?', {'entities': [(0, 7, 'model')]}), ('Oneplus 8 ki ki color e ache?', {'entities': [(0, 9, 'model')]}), ('oneplus 7t price?', {'entities': [(0, 9, 'model')]}), ('Poco X3 pro international global hobena,,', {'entities': [(0, 7, 'model')]}), ('redmi Note 10 int global 4/64 available?', {'entities': [(0, 11, 'model')]}), ('Realme 7 unofficial koto 6/64', {'entities': [(0, 9, 'model')]}), ('redmi Note 10 pro max Int. Global official, Price???', {'entities': [(0, 11, 'model')]}), ('xiaomi redmi redmi k40 avillable  with price??', {'entities': [(13, 22, 'model')]}), ('realme 8 official price?', {'entities': [(0, 8, 'model')]}), ('Realme 7 pro unofficial price koto....', {'entities': [(0, 9, 'model')]}), ('Realme 7 pro available?', {'entities': [(0, 9, 'model')]}), ('Poco X3 pro Int. Global official, seriously?', {'entities': [(0, 7, 'model')]}), ('mi 11 lite blackcolor ase ?', {'entities': [(0, 10, 'model')]}), ('redmi Note 10 white colour ta ache ki', {'entities': [(0, 11, 'model')]}), ('Redmi 9 4/64 (Chinese) Full Intact ? নাকি দোকানে রিপলি করা?', {'entities': [(0, 7, 'model')]}), ('redmi note 9 pro ta ki international global?', {'entities': [(0, 11, 'model')]}), ('Redmi 9 Chinese 3/4 পিছ নিলে কত রাখবেন, আর 9A. আছে কিনা?', {'entities': [(0, 7, 'model')]}), ('Bhaia OnePlus 8 ki ki color variant ase?', {'entities': [(6, 15, 'model')]}), ('Sir redmi Note 10 pro max ami nabo', {'entities': [(4, 15, 'model')]}), ('Redmi 9 4/64••••••11999/-(Chinese)', {'entities': [(0, 7, 'model')]}), ('ভাই Realme 8 pro 6/128 এইটা কি আপনাদের কাছে আছে এখন। আর থাকলে দাম কতো বলবেন', {'entities': [(4, 12, 'model')]}), ('redmi k40 pro price', {'entities': [(0, 9, 'model')]}), ('Poco M2 Pro', {'entities': [(0, 11, 'model')]}), ('REALME 8 (30 watt) full charge hote somoy ney almost 66 min but redmi Note 10 (33 watt) somoy ney almost 102 min . Same battery capacity te ato time difference keno???', {'entities': [(0, 8, 'model')]}), ('redmi Note 10 pro...International global ase ki??', {'entities': [(0, 11, 'model')]}), ('Realme 7 pro color konta ache? And kalke ashle pawa jabe confirm?', {'entities': [(0, 9, 'model')]}), ('Realme 8 unofficial price koto', {'entities': [(0, 8, 'model')]}), ('Mi 11 lite available?', {'entities': [(0, 10, 'model')]}), ('realme 8 pro 8/128 unoffical price kotho', {'entities': [(0, 8, 'model')]}), ('redmi Note 10 price ke fixed & products ke available?', {'entities': [(0, 11, 'model')]}), ('redmi Note 10 4/64 ta ki Global Variant naki Indian Variant??', {'entities': [(0, 11, 'model')]}), ('Best price of Poco X3 pro', {'entities': [(14, 21, 'model')]}), ('redmi Note 10 ki global price naki indian price??', {'entities': [(0, 11, 'model')]}), ('redmi Note 10 pro official kobe ashbe?', {'entities': [(0, 11, 'model')]}), ('poco x3 6/128 available? Or unofficial?', {'entities': [(0, 7, 'model')]}), ('redmi Note 10 pro Max.ki International global?', {'entities': [(0, 11, 'model')]}), ('Vai redmi Note 10 er price ta ektu komaben na?', {'entities': [(4, 15, 'model')]}), ('redmi Note 10 pro unoffisial price', {'entities': [(0, 11, 'model')]}), ('redmi Note 10pro (64mp) er tar 8/128gb er price koto?', {'entities': [(0, 11, 'model')]}), ('redmi Note 10 pro international availabe? na thakle kobe paoa jabe?', {'entities': [(0, 11, 'model')]}), ('Mi 11 lite 5g ashce?', {'entities': [(0, 10, 'model')]}), ('redmi Note 10 pro এর দাম কি প্রতিদিন ৪০০/৫০০ করে বাড়ে নাকি', {'entities': [(0, 11, 'model')]}), ('Poco f3 8/256 price?', {'entities': [(0, 7, 'model')]}), ('redmi Note 10 4/64 international?', {'entities': [(0, 11, 'model')]}), ('redmi Note 10 pro chinese ta ki available?', {'entities': [(0, 11, 'model')]}), ('Poco x3 6/64 asa naki', {'entities': [(0, 7, 'model')]}), ('Oneplus 9pro price ?', {'entities': [(0, 9, 'model')]}), ('redmi Note 10 ki dite parben? 4/64 indian.', {'entities': [(0, 11, 'model')]}), ('Need poco x3', {'entities': [(5, 12, 'model')]}), ('redmi Note 10 pro 8/128 global ki ase', {'entities': [(0, 11, 'model')]}), ('Samsung Galaxy A52 available hbe ki???r hole prices koto???', {'entities': [(8, 17, 'model')]}), ('redmi Note 10 pro max official price?', {'entities': [(0, 11, 'model')]}), ('redmi Note 10 Pro ( International)  global version হবে??', {'entities': [(0, 11, 'model')]}), ('Poco f3 pro er price?', {'entities': [(0, 7, 'model')]}), ('Realme x2 pro available?', {'entities': [(0, 8, 'model')]}), ('poco f3 pro ber houar chances ache?', {'entities': [(0, 7, 'model')]}), ('Redmi Note 9 ta ki available ace ?', {'entities': [(0, 11, 'model')]}), ('Poco F3 limited bolte koyta stock a ase bujhacchen?', {'entities': [(0, 7, 'model')]}), ('redmi Note 10 4/64 Aikhan a price 16690tk', {'entities': [(0, 11, 'model')]}), ('8/256 poco f3 price', {'entities': [(6, 13, 'model')]}), ('8 tarikh ki redmi Note 10 pro er price akoi thakbe? ar kono discount hbe kina aktu bolben plz.', {'entities': [(12, 23, 'model')]}), ('Mi 11 lite koto?', {'entities': [(0, 10, 'model')]}), ('Poco f3 5g global white colour hobe?', {'entities': [(0, 7, 'model')]}), ('poco m3 official?', {'entities': [(0, 7, 'model')]}), ('Poco F3 8/128 Price Pls,', {'entities': [(0, 7, 'model')]}), ('Poco F3 er ki 8/128 variant asbe?', {'entities': [(0, 7, 'model')]}), ('F3 dia ki hobo....redmi k40 pro lagbo', {'entities': [(18, 27, 'model')]}), ('Poco x3', {'entities': [(0, 7, 'model')]}), ('redmi Note 10 pro international version টা নাই ??', {'entities': [(0, 11, 'model')]}), ('Poco x3 nite chai,,,', {'entities': [(0, 7, 'model')]}), ('redmi Note 10 4/64 ekhono ki ei dame paoya jae', {'entities': [(0, 11, 'model')]}), ('where adyan delivery update.. please update adyan delivery stock.. our demund redmi Note 10 pro', {'entities': [(78, 89, 'model')]}), ('radmi redmi Note 10pro max... global version ta ki available...?', {'entities': [(6, 17, 'model')]}), ('Vai redmi Note 10 4/64 ভ্যারিয়েন্টে অন্যরা নিচ্ছে ১৫৯৯৯/১৬০০০ আর আপনারা ১৬৬৯০', {'entities': [(4, 15, 'model')]}), ('redmi Note 10 (6/128) INT GLOBAL...still available with colour?', {'entities': [(0, 11, 'model')]}), ('Tnx vai poco x3 peyesi intex phone !', {'entities': [(8, 15, 'model')]}), ('redmi Note 10 pro max nite cassi?', {'entities': [(0, 11, 'model')]}), ('Realme 8 price koto', {'entities': [(0, 8, 'model')]}), ('redmi Note 10 official available?', {'entities': [(0, 11, 'model')]}), ('Mi note 9 pro max 6/128 ??', {'entities': [(0, 7, 'model')]}), ('আপনারা Mi 11x pro আনবেন বা redmi k40 pro global rom flash করে দিতে পারবেন??', {'entities': [(27, 36, 'model')]}), ('redmi k40 এর প্রাইজ কত?', {'entities': [(0, 9, 'model')]}), ('redmi k40 price plz', {'entities': [(0, 9, 'model')]}), ('Poco F3 er price koto ???', {'entities': [(0, 7, 'model')]}), ('redmi k40 pro+ ki ashar kono chance acce??', {'entities': [(0, 9, 'model')]}), ('redmi k40 pro+ hobe?', {'entities': [(0, 9, 'model')]}), ('redmi k40 pro er price koto?', {'entities': [(0, 9, 'model')]}), ('Mi 11 lite ki available?', {'entities': [(0, 10, 'model')]}), ('redmi k40 ki available?', {'entities': [(0, 9, 'model')]}), ('redmi Note 10 ,6/128 ,international global থাকলে দেন,মিরপুর থেকে নিয়ে আসবো।', {'entities': [(0, 11, 'model')]}), ('redmi Note 10 international hobe?', {'entities': [(0, 11, 'model')]}), ('Cash on delivery hobe..? Tahole redmi Note 10 pro max nibo?', {'entities': [(32, 43, 'model')]}), ('Exchange possible with Poco m2 pro?', {'entities': [(23, 34, 'model')]}), ('redmi Note 10 pro 8/128 price koto?', {'entities': [(0, 11, 'model')]}), ('poco m2 pro (6/64) available?', {'entities': [(0, 11, 'model')]}), ('redmi Note 10 global 6/128  dhaka r বাইরে possible?', {'entities': [(0, 11, 'model')]}), ('Poco x3 ache??', {'entities': [(0, 7, 'model')]}), ('redmi Note 10 er china Ta Ashbe Kobe?', {'entities': [(0, 11, 'model')]}), ('redmi Note 10 pro ki India or international', {'entities': [(0, 11, 'model')]}), ('Redmi 9 CN er dam barlo keno? Eta to 11500/- diya bikri hoto!', {'entities': [(0, 7, 'model')]}), ('Radmi redmi Note 10pro max 6/128 available..?', {'entities': [(6, 17, 'model')]}), ('Poco M2 pro ta ki available', {'entities': [(0, 11, 'model')]}), ('Redmi note 9 pro 4/64 available ase', {'entities': [(0, 11, 'model')]}), ('Poco x3 proo 6/128 gb kih ashe nai', {'entities': [(0, 7, 'model')]}), ('redmi Note 10 pro er prosser konta vai..?732 নাকি ৬৭০?', {'entities': [(0, 11, 'model')]}), ('redmi Note 10 6/128 lagbe', {'entities': [(0, 11, 'model')]}), ('mi redmi Note 10prokoto', {'entities': [(3, 14, 'model')]}), ('Black shark 4  ki available ase?', {'entities': [(0, 11, 'model')]}), ('redmi Note 10 unofficial tar price koto.??', {'entities': [(0, 11, 'model')]}), ('redmi Note 10 kon variant aita?', {'entities': [(0, 11, 'model')]}), ('Amr kas thaka 10tk base nesa redmi Note 10', {'entities': [(29, 40, 'model')]}), ('redmi Note 10 (4/64 ) unofficial price koto?', {'entities': [(0, 11, 'model')]}), ('redmi Note 10 4/64 price koto Mirpur 10 barnch e', {'entities': [(0, 11, 'model')]}), ('Redmi 9 cn global hoba', {'entities': [(0, 7, 'model')]}), ('Redmi 9 CN (4/64) Black 12.5k', {'entities': [(0, 7, 'model')]}), ('Redmi Note 9 pro 6/128 Unofficial price koto.', {'entities': [(0, 11, 'model')]}), ('Poco F3 কবে পাবো?.', {'entities': [(0, 7, 'model')]}), ('Redmi 9 cn mane ki', {'entities': [(0, 7, 'model')]}), ('Iphone 12 pro max 128gb bd Official phone ase? Daam koto?', {'entities': [(0, 9, 'model')]}), ('xiomi Android mini tv box price please', {'entities': [(8, 18, 'model')]}), ('Poco m2 pro available?  R price koto, unofficial?', {'entities': [(0, 11, 'model')]}), ('Poco x3 pro 8/256 global price', {'entities': [(0, 7, 'model')]}), ('redmi Note 10 Pro ki international naki Indian?', {'entities': [(0, 11, 'model')]}), ('Redmi 10x er price kombe kbe? kisudin agei na 14k silo.', {'entities': [(0, 7, 'model')]}), ('redmi Note 10 pro indian na global?', {'entities': [(0, 11, 'model')]}), ('redmi Note 10 international global ase ki???', {'entities': [(0, 11, 'model')]}), ('redmi Note 10 4/64 এটা কি ইন্ডিয়ান নাকি ইন্টারন্যাশনাল?', {'entities': [(0, 11, 'model')]}), ('Radmi redmi Note 10 pro 6/128 global version', {'entities': [(6, 17, 'model')]}), ('Poco x3 pro er dam 30k howa drkar..', {'entities': [(0, 7, 'model')]}), ('redmi Note 10 6/128 ki Global?', {'entities': [(0, 11, 'model')]}), ('poco x3 pro 8/128 , 26k kbe hbe?', {'entities': [(0, 7, 'model')]}), ('redmi Note 10 pro 6/128 unofficial price kotho', {'entities': [(0, 11, 'model')]}), ('redmi Note 10 er dam kombe kobe akhono price onk high indian sate compare korle. 4/64 15500tk 6/128 18k hobe kokhon?', {'entities': [(0, 11, 'model')]}), ('redmi Note 10 pro max টা কি আছে না কি আনবেন?', {'entities': [(0, 11, 'model')]}), ('Asus ZenFone 8 ki er price plz?', {'entities': [(5, 14, 'model')]}), ('poco m2 pro available?', {'entities': [(0, 11, 'model')]}), ('iphone xr available?', {'entities': [(0, 8, 'model')]}), ('redmi Note 10 global price?', {'entities': [(0, 11, 'model')]}), ('redmi Note 10 pro 6/128 which version?', {'entities': [(0, 11, 'model')]}), ('redmi Note 10 pro 6/128 22,500 ki indian???', {'entities': [(0, 11, 'model')]}), ('Vaiya redmi k40 kobe asba?', {'entities': [(6, 15, 'model')]}), ('vai poco m2 pro er sathe exchange kora jabe ki?', {'entities': [(4, 15, 'model')]}), ('Readmi redmi k40 কি আসছে?', {'entities': [(7, 16, 'model')]}), ('redmi Note 10 pro max er price koto 6/128', {'entities': [(0, 11, 'model')]}), ('আমার ইমারজেন্সি redmi Note 10', {'entities': [(16, 27, 'model')]}), ('redmi Note 10 6/128 color ki ki ache', {'entities': [(0, 11, 'model')]}), ('redmi Note 10 ki official ?', {'entities': [(0, 11, 'model')]}), ('redmi Note 10 pro nithe cai', {'entities': [(0, 11, 'model')]}), ('redmi Note 10 pro optimisation issue ki thik hoise?', {'entities': [(0, 11, 'model')]}), ('What is the difference between redmi Note 10 international global and Indian version', {'entities': [(31, 42, 'model')]}), ('redmi Note 10 pro max?', {'entities': [(0, 11, 'model')]}), ('redmi Note 10 pro max available ?', {'entities': [(0, 11, 'model')]}), ('redmi Note 10pro version kunta', {'entities': [(0, 11, 'model')]}), ('Assa kaw ki bolben jodi indian global ar redmi Note 10pro nai tahola pore agular network service off hoya jaba', {'entities': [(41, 52, 'model')]}), ('poco f3 kkn available hobe?', {'entities': [(0, 7, 'model')]}), ('redmi Note 10 pro max 6/128 price', {'entities': [(0, 11, 'model')]}), ('redmi Note 10 pro 6/128 ki indian?', {'entities': [(0, 11, 'model')]}), ('poco x3 pro available?', {'entities': [(0, 7, 'model')]}), ('redmi Note 10 pro 6, 128 nite cacchi,', {'entities': [(0, 11, 'model')]}), ('Poco X3 pro unofficial ache Vai..??', {'entities': [(0, 7, 'model')]}), ('Sir redmi Note 10 pro 4/64', {'entities': [(4, 15, 'model')]}), ('Tik ace price. redmi Note 10s ki 18k majhe paoya jabe viya?', {'entities': [(15, 26, 'model')]}), ('redmi Note 10(4/64 GB) price?', {'entities': [(0, 11, 'model')]}), ('redmi Note 10 pro (international global)  available?', {'entities': [(0, 11, 'model')]}), ('redmi Note 10-4/64 Indian Price?', {'entities': [(0, 11, 'model')]}), ('redmi k40 gaming  edition  asbe kobe', {'entities': [(0, 9, 'model')]}), ('Poco f3pro dorkar  kobe pawa jabe??', {'entities': [(0, 7, 'model')]}), ('Poco x3 pro int ase', {'entities': [(0, 7, 'model')]}), ('mi 11 lite 4g er price 6/64', {'entities': [(0, 10, 'model')]}), ('Poco m2pro ki r nai?', {'entities': [(0, 7, 'model')]}), ('Poco m2 pro available or not?', {'entities': [(0, 11, 'model')]}), ('redmi Note 10 pro bronze colour available ase.', {'entities': [(0, 11, 'model')]}), ('redmi Note 10 pro max price', {'entities': [(0, 11, 'model')]}), ('India redmi Note 10 pro er camera 64 naki 108 mp? Aktu clear bolben?', {'entities': [(6, 17, 'model')]}), ('mi 11 lite 6/128 price', {'entities': [(0, 10, 'model')]}), ('redmi Note 10 pro (international)  ase?', {'entities': [(0, 11, 'model')]}), ('Poco x3 pro ki indian naki international ? R 8/128 ki available ?', {'entities': [(0, 7, 'model')]}), ('redmi Note 10i available?', {'entities': [(0, 11, 'model')]}), ('Poco x3 pro bronze colour ta ace?', {'entities': [(0, 7, 'model')]}), ('redmi Note 10 এর গ্লাস পেপার ও কাবার পাওয়া যাবে?', {'entities': [(0, 11, 'model')]}), ('redmi Note 10 pro 6/64 ache?  Thakle price??', {'entities': [(0, 11, 'model')]}), ('redmi Note 10 pro 20 jokon hoba tokon nibo.', {'entities': [(0, 11, 'model')]}), ('redmi Note 10 pro max ki exchange kora jabe amar Samsung A71 er সাথে', {'entities': [(0, 11, 'model')]}), ('Is the redmi Note 10 pro have that 108 mp rare camera?', {'entities': [(7, 18, 'model')]}), ('redmi Note 10 pro international', {'entities': [(0, 11, 'model')]}), ('Redmi 10pro Available Ache ki?Order Korte Parbo???', {'entities': [(0, 7, 'model')]}), ('Poco x3 pro phantom black ta hbe apndr kase? Shop e eshe nitam..', {'entities': [(0, 7, 'model')]}), ('POCO X3 pro indian or global?', {'entities': [(0, 7, 'model')]}), ('Poco X3 pro ki indian variant...', {'entities': [(0, 7, 'model')]}), ('Radmi redmi Note 10 pro max available.....??', {'entities': [(6, 17, 'model')]}), ('Dam kombe kobe. redmi Note 10', {'entities': [(16, 27, 'model')]}), ('Poco X3 Pro Price 6 128', {'entities': [(0, 7, 'model')]}), ('redmi Note 10 pro max price', {'entities': [(0, 11, 'model')]}), ('redmi Note 10 pro 6/128 blue colour available???', {'entities': [(0, 11, 'model')]}), ('redmi Note 10 pro international global ta lagbe', {'entities': [(0, 11, 'model')]}), ('poco x3 pro indian global or international global?', {'entities': [(0, 7, 'model')]}), ('Official  redmi Note 10 pro 6/128 price plz?', {'entities': [(10, 21, 'model')]}), ('Redmi note 9', {'entities': [(0, 11, 'model')]}), ('Poco x3 pro kon variant???', {'entities': [(0, 7, 'model')]}), ('redmi Note 10 pro 6/128 are price ki 20k te asba nah', {'entities': [(0, 11, 'model')]}), ('redmi Note 10 4/46 international global price plz?', {'entities': [(0, 11, 'model')]}), ('Jai hok poco x3 pror dam 25000 raksen.dekhe valoi laglo, but bidhi bam amar kache ace 16k, ekhn 25k kmne kori', {'entities': [(8, 15, 'model')]}), ('redmi Note 10 pro max kom chai aro', {'entities': [(0, 11, 'model')]}), ('poco x3 pro er pic tule post koren', {'entities': [(0, 7, 'model')]}), ('redmi Note 10- 6/128 available for today? Please let me know fast!', {'entities': [(0, 11, 'model')]}), ('redmi Note 10 6/128 (international global) black ta available ache?', {'entities': [(0, 11, 'model')]}), ('redmi Note 10 pro (international global) ta hbe ki???', {'entities': [(0, 11, 'model')]}), ('Poco m2 pro 4/64  ki available?  Hole price koto?', {'entities': [(0, 11, 'model')]}), ('redmi Note 10 ta konta....', {'entities': [(0, 11, 'model')]}), ('Realme c25 .?', {'entities': [(0, 9, 'model')]}), ('redmi Note 10 indian Global e ki Super amoled na amoled display?', {'entities': [(0, 11, 'model')]}), ('redmi Note 10 Pro 6/128 eta ki international global hoi na......', {'entities': [(0, 11, 'model')]}), ('Poco X3 pro international global ta 25k te den please', {'entities': [(0, 7, 'model')]}), ('redmi Note 10 asee??', {'entities': [(0, 11, 'model')]}), ('redmi Note 10 pro Max 6/128•••••26500/-(Global)', {'entities': [(0, 11, 'model')]}), ('দুপুরে ফোন দিলাম Redmi 9A 4/64•••••9000/-  (Chinese) স্টক নাই। আবার এলো কোথা থেকে?', {'entities': [(17, 24, 'model')]}), ('redmi Note 10 pro 6/128 official global version koto price??not pro max just redmi Note 10 pro', {'entities': [(0, 11, 'model')]}), ('Vai oneplus 8 or 8t কি ৩৫ থেকে ৪০ এর ভিতরে পাওয়া যাবে??', {'entities': [(4, 13, 'model')]}), ('Redmi note 9 ki official phone?', {'entities': [(0, 11, 'model')]}), ('redmi Note 10 tolarbage dite parben?6/128,international global,gray color', {'entities': [(0, 11, 'model')]}), ('poco x3 prooo neye nebo naki', {'entities': [(0, 7, 'model')]}), ('Vai redmi Note 10 pro max name ar kono phone to Globale launched hoyni ta vai redmi Note 10 pro max (Global) aita koi pailen???', {'entities': [(4, 15, 'model')]}), ('Any update of redmi k40 ?', {'entities': [(14, 23, 'model')]}), ('redmi Note 10 pro এইখানে প্রাইস ঠিকি দিছেন ২৩০০০। অথচ Qcoom য়ে ২৪০০০ টাকা দাম দিয়া ওইটার ওপরে অফার দেওয়া। কি টেকনিক।', {'entities': [(0, 11, 'model')]}), ('ভাই redmi Note 10 pro এর মধ্যে কি 108 mp নাকি,?? 64mp ??', {'entities': [(4, 15, 'model')]}), ('Realme X2 global version ki available', {'entities': [(0, 8, 'model')]}), ('redmi Note 10 pro max 23000 টাকা হবে?', {'entities': [(0, 11, 'model')]}), ('oneplus nord n10 5g ki official?', {'entities': [(0, 12, 'model')]}), ('redmi Note 10 pro max Indian or International', {'entities': [(0, 11, 'model')]}), ('Poco f3 ta kobe anben??', {'entities': [(0, 7, 'model')]}), ('redmi Note 10 pro max er golden colour ta ki ache', {'entities': [(0, 11, 'model')]}), ('oneplus 9R India te 40000 hoile Bangladesh a kivabe 52990 hoi?', {'entities': [(0, 9, 'model')]}), ('Oneplus 7t ki available??', {'entities': [(0, 9, 'model')]}), ('Poco x3 (Non NFC)', {'entities': [(0, 7, 'model')]}), ('Vaiya... oneplus nord 8/128 unofficial er price koto porbe..?', {'entities': [(9, 21, 'model')]}), ('OnePlus 9R ar price kom hoiya gele nah', {'entities': [(0, 9, 'model')]}), ('oneplus 8 T 48k hobe', {'entities': [(0, 9, 'model')]}), ('Oneplus 8 glow colour available?', {'entities': [(0, 9, 'model')]}), ('poco x3 6/128 global available?', {'entities': [(0, 7, 'model')]}), ('Tecno spark 7 pro কত টাকা?', {'entities': [(0, 11, 'model')]}), ('Mi 11 lite 31999 ei price ki official na unofficial??', {'entities': [(0, 10, 'model')]}), ('redmi Note 10 pro max 8/128', {'entities': [(0, 11, 'model')]}), ('ভাইয়া redmi Note 10 pro 8/128 অনলাইনে পাওয়া যাবে', {'entities': [(6, 17, 'model')]}), ('redmi Note 10 pro 8/128 bronze colour ase.', {'entities': [(0, 11, 'model')]}), ('redmi k40 is better thn mi 11 lite', {'entities': [(0, 9, 'model')]}), ('Poco x3 pro international', {'entities': [(0, 7, 'model')]}), ('mi 11 lite 31k online price r apnader ki offer bah32k', {'entities': [(0, 10, 'model')]}), ('Mi 11x/poco f3/redmi k40 ar price koto??', {'entities': [(15, 24, 'model')]}), ('Vai aita ki mi 11 lite sd780g 5g??', {'entities': [(12, 22, 'model')]}), ('এই ফোন ৩২ দিয়ে কে নিবে redmi k40 far far better.', {'entities': [(23, 32, 'model')]}), ('Mi 11 lite 5G kobe ashbe', {'entities': [(0, 10, 'model')]}), ('redmi Note 10 line up ta Global varient ashbena??? eta to maybe Indian version', {'entities': [(0, 11, 'model')]}), ('xiaomi redmi note 9 pro max. 6/128.', {'entities': [(7, 18, 'model')]}), ('redmi Note 10 int..17000 rakha jai??', {'entities': [(0, 11, 'model')]}), ('redmi Note 10 6/128 koto??', {'entities': [(0, 11, 'model')]}), ('Poco f3 official kobe asbe', {'entities': [(0, 7, 'model')]}), ('Poco x3 pro global price?', {'entities': [(0, 7, 'model')]}), ('Poco x3 unofficial price pls', {'entities': [(0, 7, 'model')]}), ('redmi Note 10 pro global or indian?', {'entities': [(0, 11, 'model')]}), ('redmi Note 10 ki official??', {'entities': [(0, 11, 'model')]}), ('redmi Note 10 6/128 global version available?', {'entities': [(0, 11, 'model')]}), ('redmi Note 10 international 6/128 Price?', {'entities': [(0, 11, 'model')]}), ('redmi Note 10 6/128 ki global version', {'entities': [(0, 11, 'model')]}), ('Redmi 9 power ki official naki unofficial?', {'entities': [(0, 7, 'model')]}), ('redmi Note 10 indian ta white ta ache??', {'entities': [(0, 11, 'model')]}), ('oneplus nord hobe??', {'entities': [(0, 12, 'model')]}), ('oneplus 8t (12/256) silver colour available?', {'entities': [(0, 9, 'model')]}), ('Poco F3 Er Dam Koman Na Kn Bujhi Na', {'entities': [(0, 7, 'model')]}), ('oneplus 7 pro intarnational hoba ki', {'entities': [(0, 9, 'model')]}), ('Poco f3 er price koto?', {'entities': [(0, 7, 'model')]}), ('Poco x3 pro 6/128 official = 28 k...', {'entities': [(0, 7, 'model')]}), ('redmi Note 10 pro available ?', {'entities': [(0, 11, 'model')]}), ('redmi Note 10pro ki 108mp camerar', {'entities': [(0, 11, 'model')]}), ('Vai poco m3 er price ta ektu bolben', {'entities': [(4, 11, 'model')]}), ('Mi 11 lite yellow color asba ki??', {'entities': [(0, 10, 'model')]}), ('redmi Note 10 ki official??', {'entities': [(0, 11, 'model')]}), ('Mi 11 lite colour konta hobe??', {'entities': [(0, 10, 'model')]}), ('Sir redmi note 9 pro 6/64 price in bangladesh official koto please bolen', {'entities': [(4, 15, 'model')]}), ('redmi Note 10 pro indian?', {'entities': [(0, 11, 'model')]}), ('Plz replay redmi Note 10 pro max price', {'entities': [(11, 22, 'model')]}), ('redmi 10x 4/128 এটার দাম কত ?', {'entities': [(0, 7, 'model')]}), ('redmi Note 10 6/128 int dam komer sombabona aca? 1mas er modda.?', {'entities': [(0, 11, 'model')]}), ('Redmi note 9 pro 6/128 GB price', {'entities': [(0, 11, 'model')]}), ('redmi Note 10 pro max koto porbe', {'entities': [(0, 11, 'model')]}), ('Is redmi Note 10 Gobal variant available', {'entities': [(3, 14, 'model')]}), ('ভাই, redmi Note 10 মোবাইলটির International global টা কি Chinese, এটাতে কি Google এর Application গুলি By default use করা  যাবে?', {'entities': [(5, 16, 'model')]}), ('redmi Note 10 pro 6/128 unofficial price plz', {'entities': [(0, 11, 'model')]}), ('redmi Note 10 Pro (6/128) - International Global  কতো?', {'entities': [(0, 11, 'model')]}), ('redmi Note 10 6/128 current price?', {'entities': [(0, 11, 'model')]}), ('Unofficially redmi Note 10 4/64 price ekhon koto', {'entities': [(13, 24, 'model')]}), ('redmi Note 10-4/64 Indian price?', {'entities': [(0, 11, 'model')]}), ('Poco F3 available??', {'entities': [(0, 7, 'model')]}), ('Poco f3 black available?', {'entities': [(0, 7, 'model')]}), ('redmi Note 10 4/ 128 price koto', {'entities': [(0, 11, 'model')]}), ('redmi Note 10 pro max location patiya mobile lagba', {'entities': [(0, 11, 'model')]}), ('redmi Note 10 koto', {'entities': [(0, 11, 'model')]}), ('redmi Note 10 pro official tar price kto???8/128', {'entities': [(0, 11, 'model')]}), ('Xaomi redmi Note 10 lite kemon?', {'entities': [(6, 17, 'model')]}), ('poco x3 6/128 unofficial price plc?', {'entities': [(0, 7, 'model')]}), ('redmi Note 10 pro 108mp ache?', {'entities': [(0, 11, 'model')]}), ('redmi Note 10 pro (6/128) indian er price koto?', {'entities': [(0, 11, 'model')]}), ('Redmi 9A koto GB memory card support kore?', {'entities': [(0, 7, 'model')]}), ('16500 price rakhle valo hobe redmi Note 10', {'entities': [(29, 40, 'model')]}), ('redmi Note 10 6/128 unofficial Price koto', {'entities': [(0, 11, 'model')]}), ('redmi Note 10 ..6/64 koto niben... unofficial', {'entities': [(0, 11, 'model')]}), ('poco X3  pro কি official??', {'entities': [(0, 7, 'model')]}), ('redmi Note 10 ki official??', {'entities': [(0, 11, 'model')]}), ('poco m3 pro 5g ???', {'entities': [(0, 7, 'model')]}), ('Poco x3 pro price ki komano jabe?', {'entities': [(0, 7, 'model')]}), ('Vai redmi Note 10 (IND) er price komar wait kortesilam...ulta baraya dilen dekhi', {'entities': [(4, 15, 'model')]}), ('redmi 9T prize??', {'entities': [(0, 7, 'model')]}), ('Poco F3 kobe pabo', {'entities': [(0, 7, 'model')]}), ('redmi Note 10 pro 8/128 er price koto?', {'entities': [(0, 11, 'model')]}), ('redmi k40 pro asbe kobe?', {'entities': [(0, 9, 'model')]}), ('redmi k40 ki available', {'entities': [(0, 9, 'model')]}), ('Poco x3 8/128 ki available?', {'entities': [(0, 7, 'model')]}), ('Realme Narzo 30a Avilable.?', {'entities': [(0, 12, 'model')]}), ('Realme 8 unofficiall ache.?', {'entities': [(0, 8, 'model')]}), ('poco m2 pro ace ?', {'entities': [(0, 11, 'model')]}), ('Poco X3 pro official e 26k .', {'entities': [(0, 7, 'model')]}), ('redmi Note 10 pro max r 1k komle kinbo,..!', {'entities': [(0, 11, 'model')]}), ('redmi Note 10 pro official kobe asbe?', {'entities': [(0, 11, 'model')]}), ('redmi Note 10 4/64 er ki ki colour available?', {'entities': [(0, 11, 'model')]}), ('redmi Note 10 pro 108 Mp camera variant ta ki available 8/128', {'entities': [(0, 11, 'model')]}), ('xiaomi redmi redmi Note 10 pro & pro max international or Indian?', {'entities': [(13, 24, 'model')]}), ('redmi Note 10 5g official payle onk best hoyto', {'entities': [(0, 11, 'model')]}), ('oneplus 8t (12/256) Silver colour available?', {'entities': [(0, 9, 'model')]}), ('Redmi note 9 pro max 6/64 ki available...', {'entities': [(0, 11, 'model')]}), ('redmi Note 10 pro max orege colar ta ki available?', {'entities': [(0, 11, 'model')]}), ('redmi Note 10 Pro Max official নাকি ভাই', {'entities': [(0, 11, 'model')]}), ('Redmi 9 price plz', {'entities': [(0, 7, 'model')]}), ('Oneplus 8 pro 8/128 price?', {'entities': [(0, 9, 'model')]}), ('Poco m3 pro  kobe pawa jabe,  janaben kindly..?', {'entities': [(0, 7, 'model')]}), ('MI 11 Pro আনঅফিশিয়াল কবে নাগাদ আসতে পারে? প্রাইস কত হবে?', {'entities': [(0, 9, 'model')]}), ('Poco x3 Pro 8/128 available?', {'entities': [(0, 7, 'model')]}), ('Mi 11 lite 5g...??', {'entities': [(0, 10, 'model')]}), ('Poco x3 indian koto?', {'entities': [(0, 7, 'model')]}), ('"redmi Note 10 4/64 17190/- Indian" eitar warrenty,guarenty ?', {'entities': [(1, 12, 'model')]}), ('Poco X3 pro 6/128 ata ki ind global?', {'entities': [(0, 7, 'model')]}), ('Redmi 9 4/64 price koto???', {'entities': [(0, 7, 'model')]}), ('Mi 11 lite available?', {'entities': [(0, 10, 'model')]}), ('Mi 11 pro or Ultra কবে আসবে বা পাবো', {'entities': [(0, 9, 'model')]}), ('oneplus 8 ki dual sim.?', {'entities': [(0, 9, 'model')]}), ('redmi Note 10 official  koto-?', {'entities': [(0, 11, 'model')]}), ('Redmi 9 power  ki 64 sd card support  hobey', {'entities': [(0, 7, 'model')]}), ('POCO F3 price??', {'entities': [(0, 7, 'model')]}), ('redmi k40 pro asca', {'entities': [(0, 9, 'model')]}), ('redmi Note 10 Pro Max Super AMOLED display 6/128 sky color ta koto rskha jabe akhon nibo', {'entities': [(0, 11, 'model')]}), ('redmi Note 10 6/128 ki International?', {'entities': [(0, 11, 'model')]}), ('redmi Note 10 ki official?', {'entities': [(0, 11, 'model')]}), ('Poco X3 pro ata India naki International', {'entities': [(0, 7, 'model')]}), ('bhai redmi Note 10 dekhte paro... R ai page 1000% trusted amr agher phn eta thki anaisi', {'entities': [(5, 16, 'model')]}), ('redmi 9 power er price koto vai?', {'entities': [(0, 7, 'model')]}), ('Redmi 9 power koto gb', {'entities': [(0, 7, 'model')]}), ('redmi Note 10 pro 108mp(6/128) official price koto', {'entities': [(0, 11, 'model')]}), ('realme 7 pro dekhilam shreshtho te 19500 redmi note 9 prp O same', {'entities': [(0, 9, 'model')]}), ('28k diye official redmi Note 10 Pro (108mp) pawa jasse r ei dike 26k+ unofficial.....', {'entities': [(18, 29, 'model')]}), ('Redmi 9 powar ta ki pawa jabe vai ..', {'entities': [(0, 7, 'model')]}), ('redmi Note 10 s available??', {'entities': [(0, 11, 'model')]}), ('mi11x / poco f3 er kono update ace ?', {'entities': [(8, 15, 'model')]}), ('redmi k40', {'entities': [(0, 9, 'model')]}), ('redmi k40 er price koto?', {'entities': [(0, 9, 'model')]}), ('Oneplus 8 black/interstellar glow 8/128 available ache?', {'entities': [(0, 9, 'model')]}), ('redmi k40 price?', {'entities': [(0, 9, 'model')]}), ('Poco x3 pro', {'entities': [(0, 7, 'model')]}), ('vai poco f3 have', {'entities': [(4, 11, 'model')]}), ('redmi k40 is best as it comes with 120 hz e4 amoled + sd 870', {'entities': [(0, 9, 'model')]}), ('Poco x3 pro budget and  my choice is x3 pro', {'entities': [(0, 7, 'model')]}), ('poco x3 8/128 official ar prize koto??', {'entities': [(0, 7, 'model')]}), ('redmi k40 8/128 available?', {'entities': [(0, 9, 'model')]}), ('redmi k40 Available????', {'entities': [(0, 9, 'model')]}), ('Nije poco f3 chalai kintu budget e best poco x3 pro poco f3 ektu over price', {'entities': [(40, 47, 'model')]}), ('Desighn er dikh diye redmi k40 valo....', {'entities': [(21, 30, 'model')]}), ('redmi k40 but apnara kobe anben', {'entities': [(0, 9, 'model')]}), ('redmi Note 10 price plz?', {'entities': [(0, 11, 'model')]}), ('Bring redmi k40', {'entities': [(6, 15, 'model')]}), ('Poco f3...', {'entities': [(0, 7, 'model')]}), ('redmi k40 ki asche?', {'entities': [(0, 9, 'model')]}), ('দামই বলে দিবে Foco x3 pro  নাকি redmi k40 সেরা', {'entities': [(32, 41, 'model')]}), ('redmi k40', {'entities': [(0, 9, 'model')]}), ('redmi k40', {'entities': [(0, 9, 'model')]}), ('redmi k40 8/128 price koto?', {'entities': [(0, 9, 'model')]}), ('redmi k40', {'entities': [(0, 9, 'model')]}), ('redmi k40', {'entities': [(0, 9, 'model')]}), ('redmi k40', {'entities': [(0, 9, 'model')]}), ('redmi k40', {'entities': [(0, 9, 'model')]}), ('redmi k40', {'entities': [(0, 9, 'model')]}), ('redmi k40 gaming edition koto??', {'entities': [(0, 9, 'model')]}), ('redmi k40 gaming edition  available ?', {'entities': [(0, 9, 'model')]}), ('redmi Note 10 pro 6/128 ( International Global) price??', {'entities': [(0, 11, 'model')]}), ('poco m2 pro available', {'entities': [(0, 11, 'model')]}), ('Oneplus 8t & 9r price please?', {'entities': [(0, 9, 'model')]}), ('please bring redmi k40', {'entities': [(13, 22, 'model')]}), ('redmi Note 10 pro max ki official ta asbna??!', {'entities': [(0, 11, 'model')]}), ('Poco x3 pro 6/128 office price koto?', {'entities': [(0, 7, 'model')]}), ('redmi Note 10 pro official kobe ashte pare stock e vai.?', {'entities': [(0, 11, 'model')]}), ('redmi Note 10 pro 64 MP edition international global ase ki', {'entities': [(0, 11, 'model')]}), ('Poco f3 ace', {'entities': [(0, 7, 'model')]}), ('iphone xr 128gb?', {'entities': [(0, 8, 'model')]}), ('Poco x3 à¦\x8fà¦° à¦¡à¦¿à¦¸à¦ªà§\x8dà¦²à§‡ à¦\xa0à¦¿à¦• à¦†à¦›à§‡ à¦¶à§\x81à¦§à§\x81 à¦Ÿà¦¾à¦š à¦¨à¦·à§\x8dà¦Ÿ à¦¹à¦‡à¦¸à§‡, à¦\xa0à¦¿à¦• à¦•à¦°à¦¾à¦¤à§‡ à¦•à¦¤ à¦–à¦°à¦š à¦ªà¦°à¦¬à§‡?', {'entities': [(0, 7, 'model')]}), ('Iphone 11pro Golden available?', {'entities': [(0, 9, 'model')]}), ('oneplus 8pro price?', {'entities': [(0, 9, 'model')]}), ('iPhone X Hobe naki', {'entities': [(0, 8, 'model')]}), ('Iphone 11 battery Percentage. ?', {'entities': [(0, 9, 'model')]}), ('iphone 7 plus battery helth koto..', {'entities': [(0, 13, 'model')]}), ('Iphone 12 128 usa varient?', {'entities': [(0, 9, 'model')]}), ('iPhone 12 128 gb koto taka? battery Percentage koto', {'entities': [(0, 9, 'model')]}), ('Iphone xr Battery health?', {'entities': [(0, 8, 'model')]}), ('iphone 11 dual ase?', {'entities': [(0, 9, 'model')]}), ('iphone xr available?', {'entities': [(0, 8, 'model')]}), ('Can i exchange iphone 6s with iphone xr?', {'entities': [(15, 24, 'model')]}), ('Exchange possible oneplus 7pro 5g 8/256', {'entities': [(18, 27, 'model')]}), ('iphone xs max new available...?', {'entities': [(0, 8, 'model')]}), ('iphone 11 used price koto?? Box with charger', {'entities': [(0, 9, 'model')]}), ('Iphone x unofficial koto dam', {'entities': [(0, 8, 'model')]}), ('xiaomi redmi redmi Note 10 pro 8/128 price please.', {'entities': [(13, 24, 'model')]}), ('Realme X2 cn (8/256) apnader kache theke kinechilam..', {'entities': [(0, 8, 'model')]}), ('redmi Note 10 global price', {'entities': [(0, 11, 'model')]}), ('redmi Note 10 prp max 6/128 sell korbomatro 5din hoice nici je', {'entities': [(0, 11, 'model')]}), ('redmi Note 10 pro 108mp variant price koto', {'entities': [(0, 11, 'model')]}), ('redmi Note 10 pro unofficial hobe indian ta', {'entities': [(0, 11, 'model')]}), ('Vai Realme 8 pro tar price koto?', {'entities': [(4, 12, 'model')]}), ('redmi Note 10 pro er jei optimizing problem gula silo segula ki thik hoise?', {'entities': [(0, 11, 'model')]}), ('official kkon tke poya jbe sir? gift card dye official redmi Note 10 pro 108 mp nte parbo sir?', {'entities': [(55, 66, 'model')]}), ('Is This redmi Note 10 Pro(6/128) Official price??', {'entities': [(8, 19, 'model')]}), ('Can i exchange my iphone 8 plus (usa product with full box) with 11 pro , how much i have to add?', {'entities': [(18, 26, 'model')]}), ('redmi Note 10 (4,64) int. Global Black color Price??', {'entities': [(0, 11, 'model')]}), ('Poco x2 exchange kore mi 11 lite 8/128 nite chacchilam??', {'entities': [(22, 32, 'model')]}), ('à¦\xadà¦¾à¦‡à¦¯à¦¼à¦¾, redmi Note 10s 6/64 à¦•à¦¿ à¦¨à§‡à¦‡ à¦†à¦ªà¦¨à¦¾à¦¦à§‡à¦° à¦¶à¦ªà§‡?', {'entities': [(20, 31, 'model')]}), ('Vai galaxy a52 ase ?', {'entities': [(4, 13, 'model')]}), ('Poco f3 available  plz  price ta bolen', {'entities': [(0, 7, 'model')]}), ('Oneplus 9 price nd available ache ki?', {'entities': [(0, 9, 'model')]}), ('Vaia oneplus 9 pro 8-256 price ta koto solce , r apnader kace borto mane paoa jasce ki ?', {'entities': [(5, 14, 'model')]}), ('Oneplus 9R price 8/128', {'entities': [(0, 9, 'model')]}), ('iphone 11 ase used?', {'entities': [(0, 9, 'model')]}), ('Oneplus 9R', {'entities': [(0, 9, 'model')]}), ('Samsung galaxy redmi Note 10 price?', {'entities': [(15, 26, 'model')]}), ('Mi 9t pro?', {'entities': [(0, 9, 'model')]}), ('redmi Note 10 price pls', {'entities': [(0, 11, 'model')]}), ('redmi 9 (global) ta ke akon pwa jabe set.', {'entities': [(0, 7, 'model')]}), ('Iphone xr 128gb ki avilable bhaiya?', {'entities': [(0, 8, 'model')]}), ('Samsung redmi Note 10+ prize', {'entities': [(8, 19, 'model')]}), ('oneplus 8 pro price..?', {'entities': [(0, 9, 'model')]}), ('OnePlus 7t pro Mclaren Edition 12/price256 duel sim', {'entities': [(0, 9, 'model')]}), ('mi 11 lite price please', {'entities': [(0, 10, 'model')]}), ('redmi Note 10 pro 6/128 price please', {'entities': [(0, 11, 'model')]}), ('redmi Note 10 pro pls 6/128', {'entities': [(0, 11, 'model')]}), ('redmi Note 10 pro 6/128 price PLEASE', {'entities': [(0, 11, 'model')]}), ('OnePlus 7t pro Maclean Edison 12/256 duel sim price', {'entities': [(0, 9, 'model')]}), ('Redmi note  10 pro 6/128', {'entities': [(0, 11, 'model')]}), ('redmi Note 10 pro price  Please', {'entities': [(0, 11, 'model')]}), ('Oneplus 9 price plz', {'entities': [(0, 9, 'model')]}), ('Oneplus 9 8GB ram price?', {'entities': [(0, 9, 'model')]}), ('à¦\xadà¦¾à¦‡ poco f3 6/128 hobe?', {'entities': [(10, 17, 'model')]}), ('vai poco x3 pro koto?', {'entities': [(4, 11, 'model')]}), ('Iphone 7-8 plus konota ase?', {'entities': [(0, 8, 'model')]}), ('Oneplus 8 pro price', {'entities': [(0, 9, 'model')]}), ('Mi 10 ultra hbe bhaiya?', {'entities': [(0, 11, 'model')]}), ('Oneplus 7 128gb?', {'entities': [(0, 9, 'model')]}), ('viya oneplus 8 pro ki ace', {'entities': [(5, 14, 'model')]}), ('IPhone 7 silver edition ta aktu dakayen plz', {'entities': [(0, 8, 'model')]}), ('à¦\xadà¦¾à¦‡à¦¯à¦¼à¦¾ k20 pro 6/128 à¦\x8fà¦° à¦¦à¦¾à¦® à¦Ÿà¦¾ à¦•à¦¿ à¦\x8fà¦•à¦Ÿà§\x81 à¦•à¦®à¦¾à¦¨ à¦¯à¦¾à¦¯à¦¼ ? Exchange er à¦•à§\x8dà¦·à§‡à¦¤à§\x8dà¦°à§‡ exchange à¦•à¦°à¦¬à§‹ poco m2 officeal dia', {'entities': [(164, 171, 'model')]}), ('Mi 10 ultra ta hobe vaiya??', {'entities': [(0, 11, 'model')]}), ('Iphone 7', {'entities': [(0, 8, 'model')]}), ('IPhone 7 plus prices 128 gb piz', {'entities': [(0, 13, 'model')]}), ('Oneplus 7 ache?', {'entities': [(0, 9, 'model')]}), ('IPhone 7 plus prices piz', {'entities': [(0, 13, 'model')]}), ('Iphone 6s plsu 64 gb price pls', {'entities': [(0, 9, 'model')]}), ('redmi Note 10 pro ase vai?', {'entities': [(0, 11, 'model')]}), ('iphone 8', {'entities': [(0, 8, 'model')]}), ('IPhone 7 plus prices', {'entities': [(0, 13, 'model')]}), ('realme 8 / 8 pro available', {'entities': [(0, 8, 'model')]}), ('iPhone 7 plus prices', {'entities': [(0, 13, 'model')]}), ('Vaiya samsung galaxy s20 ultra', {'entities': [(14, 23, 'model')]}), ('Vai iPhone 12 128 gb price ta jodi bolten', {'entities': [(4, 13, 'model')]}), ('Vai poco x3 pro 8/128 koto', {'entities': [(4, 11, 'model')]}), ('Iphone 7 plus++', {'entities': [(0, 13, 'model')]}), ('Oneplus 7t', {'entities': [(0, 9, 'model')]}), ('iPhone 7 plus', {'entities': [(0, 13, 'model')]}), ('Iphone 11 fully feesh?', {'entities': [(0, 9, 'model')]}), ('Vai Realme 7pro VS Realme 8pro konta best??', {'entities': [(19, 27, 'model')]}), ('Vaiya iphone 6s plus ar price ta janlam nah', {'entities': [(6, 20, 'model')]}), ('realme narzo 20 pro nichilam.. Livewire theke.. Onk valo phn paichi..', {'entities': [(0, 12, 'model')]}), ('à¦\xadà¦¾à¦‡ oneplus 9 R à¦†à¦›à§‡', {'entities': [(10, 19, 'model')]}), ('Wbu the price ofiphone xs max with 87 plus BH', {'entities': [(16, 24, 'model')]}), ('OnePlus 7t price koto', {'entities': [(0, 9, 'model')]}), ('kico din por samsung redmi Note 10 plus nebo apnader teke', {'entities': [(21, 32, 'model')]}), ('Samsung redmi Note 10 lite er new offer ki', {'entities': [(8, 19, 'model')]}), ('Ajke ki iPhone 11 pro ache used', {'entities': [(8, 17, 'model')]}), ('Samsung redmi Note 10 lite er offer ki new', {'entities': [(8, 19, 'model')]}), ('OnePlus 7t 6/128 unofficial price koto', {'entities': [(0, 9, 'model')]}), ('OnePlus 7t er price koto', {'entities': [(0, 9, 'model')]}), ('Mi 10 ultra ta bolben bhaiya.', {'entities': [(0, 11, 'model')]}), ('redmi Note 10 aca', {'entities': [(0, 11, 'model')]}), ('Vhiya poco x3 pro ta price koto', {'entities': [(6, 13, 'model')]}), ('iphone 12 max pro ase ?', {'entities': [(0, 9, 'model')]}), ('Iphone 6s plus 64 gb price pls', {'entities': [(0, 14, 'model')]}), ('Vai apana der kace ki mi redmi Note 10 lite asa..?', {'entities': [(25, 36, 'model')]}), ('Vai kamon Samsung redmi Note 10 512gb tah koto porba', {'entities': [(18, 29, 'model')]}), ('Poco F3 ache?', {'entities': [(0, 7, 'model')]}), ('xiaomi redmi redmi Note 10 (6/128)gb price koto tk', {'entities': [(13, 24, 'model')]}), ('Blackberry key2', {'entities': [(0, 15, 'model')]}), ('OnePlus 8 6/128', {'entities': [(0, 9, 'model')]}), ('Iphone 7plus  price koto', {'entities': [(0, 8, 'model')]}), ('samsung galaxy s8 dekhte chai', {'entities': [(8, 17, 'model')]}), ('Vaiya iphone 6s plus tar price ta janlam nah akhono', {'entities': [(6, 20, 'model')]}), ('à¦\xadà¦¾à¦‡ oneplus 6 à¦•à¦¿à¦¨à¦¤à§‡ à¦šà¦¾à¦‡à¥¤', {'entities': [(10, 19, 'model')]}), ('oneplus 8 pro', {'entities': [(0, 9, 'model')]}), ('Vaia Samsung galaxy A71 phn ta dekhan....', {'entities': [(13, 22, 'model')]}), ('samsung galaxy s8 available?', {'entities': [(8, 17, 'model')]}), ('Iphone 8 plus price koto bhai?', {'entities': [(0, 8, 'model')]}), ('Vai iphone 11 new hobe?', {'entities': [(4, 13, 'model')]}), ('Galaxy redmi Note 10+', {'entities': [(7, 18, 'model')]}), ('Mate 30 pro 5g', {'entities': [(0, 7, 'model')]}), ('Bhai redmi Note 10 4/128 International varient price koto????', {'entities': [(5, 16, 'model')]}), ('Poco m2 pro', {'entities': [(0, 11, 'model')]}), ('Samsung redmi Note 10+ ta dhkte chi', {'entities': [(8, 19, 'model')]}), ('Samsung galaxy A71 phn ta dekhan vaia..', {'entities': [(8, 17, 'model')]}), ('Poco x3 nfc available?', {'entities': [(0, 11, 'model')]}), ('oneplus 7 pro ki available?', {'entities': [(0, 9, 'model')]}), ('Oneplus 7pro 6..128. Used price ta janaben plz..', {'entities': [(0, 9, 'model')]}), ('Poco x3 pro ace', {'entities': [(0, 7, 'model')]}), ('Oppo Reno3 pro er price koto', {'entities': [(0, 9, 'model')]}), ('Assalamu alaikum vaia amr kache oppo f15 ase exchange korte cacchi samsung a71sathe kichu tk add korbo....', {'entities': [(32, 39, 'model')]}), ('Poco x3 pro r dam koto', {'entities': [(0, 7, 'model')]}), ('Redmi note 9  6/128 price?', {'entities': [(0, 11, 'model')]}), ('oppo reno 3 pro à¦•à¦¤à§‹ à¦¦à¦¾à¦® à¦\x8fà¦–à¦¨', {'entities': [(0, 9, 'model')]}), ('narzo 20 ta la', {'entities': [(0, 8, 'model')]}), ('Iphone 12 max pro koto?', {'entities': [(0, 9, 'model')]}), ('Samsung redmi Note 10 hobe?', {'entities': [(8, 19, 'model')]}), ('Poco x3 ta nebo', {'entities': [(0, 7, 'model')]}), ('Vivo x60 Pro +', {'entities': [(0, 7, 'model')]}), ('Realme 5i lagbe...', {'entities': [(0, 8, 'model')]}), ('à¦¬à¦¾à¦Ÿà¦ªà¦¾à¦° à¦¹à¦² Poco X3 à¦®à¦¾à¦°à§\x8dà¦•à§‡à¦Ÿ à¦ªà§\x8dà¦°à¦¾à¦‡à¦¸ à§§à§®à§¦à§¦à§¦ à¦¹à¦¾à¦œà¦¾à¦° à¦Ÿà¦¾à¦•à¦¾', {'entities': [(26, 33, 'model')]}), ('iphone x price?', {'entities': [(0, 8, 'model')]}), ('Vhai a readmi note 8  koto', {'entities': [(11, 18, 'model')]}), ('Hirr...poco x3 india te 15000 e pawa jai', {'entities': [(7, 14, 'model')]}), ('Redmi 9 power pp plz', {'entities': [(0, 7, 'model')]}), ('Vai redmi not8 ar vivo v15 pro. Modde konta vesi valo hove plz replei', {'entities': [(18, 25, 'model')]}), ('Haha disi poco x3 er dam shune', {'entities': [(10, 17, 'model')]}), ('iphone xr brand new price please', {'entities': [(0, 8, 'model')]}), ('Poco x3 dam 16500', {'entities': [(0, 7, 'model')]}), ('Narzo 20 lagbe ace ki', {'entities': [(0, 8, 'model')]}), ('redmi Note 10 + price', {'entities': [(0, 11, 'model')]}), ('Rog phone 5 12/256', {'entities': [(0, 11, 'model')]}), ('IPhone 12 Pro 128 price?', {'entities': [(0, 9, 'model')]}), ('IPHONE 12 PRICE?', {'entities': [(0, 9, 'model')]}), ('iphone 12 pro max 24k Gold buy korar process ta ki bhai ??', {'entities': [(0, 9, 'model')]}), ('iPhone SE 2020 available?', {'entities': [(0, 9, 'model')]}), ('Iphone 12 ultra  price koto bro?', {'entities': [(0, 9, 'model')]}), ('redmi Note 10 pro max official available?', {'entities': [(0, 11, 'model')]}), ('I have need iPhone 12pro max (golden)', {'entities': [(12, 21, 'model')]}), ('redmi Note 10 pro 108MP available??', {'entities': [(0, 11, 'model')]}), ('Poco f3 ki available?', {'entities': [(0, 7, 'model')]}), ('Oneplus 8T à¦ªà§\x8dà¦°à¦¾à¦‡à¦¸ à¦•à¦¤??', {'entities': [(0, 9, 'model')]}), ("What's the difference between oneplus nord N10 official and non official? The price is way different! Can anyone answer?", {'entities': [(30, 42, 'model')]}), ('When poco f3 will be available??', {'entities': [(5, 12, 'model')]}), ('Do you have vivo x60 pro plus available????', {'entities': [(12, 19, 'model')]}), ('Galaxy note 20 ultra ki chinese naki global?', {'entities': [(0, 11, 'model')]}), ('oneplus 9 pro 8/256  official available?', {'entities': [(0, 9, 'model')]}), ('Is redmi Note 10 pro available?If it is then buy it today', {'entities': [(3, 14, 'model')]}), ('oneplus 8 pro available?', {'entities': [(0, 9, 'model')]}), ('xiaomi redmi redmi Note 10 (6+128) official pawya jabe?', {'entities': [(13, 24, 'model')]}), ('oneplus 8t global r price koto?indian r ta koto?', {'entities': [(0, 9, 'model')]}), ('Is Moto g20 available? And price?', {'entities': [(3, 11, 'model')]}), ('Oneplus 8 dual sim or single?', {'entities': [(0, 9, 'model')]}), ('Oneplus 7 or 7t available?', {'entities': [(0, 9, 'model')]}), ('oneplus 9 which varient ?', {'entities': [(0, 9, 'model')]}), ('Mi black shark 3 international?', {'entities': [(3, 14, 'model')]}), ('oneplus 7T available?', {'entities': [(0, 9, 'model')]}), ('redmi Note 10 plus price?', {'entities': [(0, 11, 'model')]}), ('poco M3 power black available?', {'entities': [(0, 7, 'model')]}), ('oneplus nord 8/128 available?', {'entities': [(0, 12, 'model')]}), ('redmi Note 10 pro 6/64 108mp unofficial price?', {'entities': [(0, 11, 'model')]}), ('india r boader khulle redmi Note 10 pro max unofficially er dam kormar kono   somvobona ase ?', {'entities': [(22, 33, 'model')]}), ('oneplus nord n 10 is avilable?', {'entities': [(0, 12, 'model')]}), ('Xaiomi redmi 9 power', {'entities': [(7, 14, 'model')]}), ('redmi note 8 moonlight blue available?', {'entities': [(0, 11, 'model')]}), ('redmi k40 [6/128] â‡\x9dâ‡\x9dâ‡\x9dâ‡\x9d 34000TK chinese  ?', {'entities': [(0, 9, 'model')]}), ('oneplus nord n10 available?', {'entities': [(0, 12, 'model')]}), ('oneplus nord official?', {'entities': [(0, 12, 'model')]}), ('redmi Note 10 [4/64](Indian global) à¦•à§Ÿà§‡à¦• à¦¦à¦¿à¦¨ à¦†à¦—à§‡à¦“ à¦¦à§‡à¦–à¦²à¦¾à¦® 16,500 à¦†à¦° à¦\x8fà¦–à¦¨ à¦¦à§‡à¦–à¦¿ 17,000 à¦\x8fà¦Ÿà¦¾ à¦ˆà¦¦ à¦…à¦«à¦¾à¦° à¦•à¦¿à¦\xadà¦¾à¦¬à§‡ à¦¹à§Ÿ?', {'entities': [(0, 11, 'model')]}), ('Poco F3 8-128/ 8-256 kobe available hobe?', {'entities': [(0, 7, 'model')]}), ('Iphone 12 128 er daam 30k hoar asha e boshe achi...', {'entities': [(0, 9, 'model')]}), ('POCO M2 made in India/global naki chinese ta?', {'entities': [(0, 7, 'model')]}), ('Poco m2 pro unofficial ta ase naki er thakle price koto', {'entities': [(0, 11, 'model')]}), ('Vai oneplus 8 international global naki indian', {'entities': [(4, 13, 'model')]}), ('Galaxy F62 dorkar, kobe available hobe? R Iqoo 7 niye asen. F3 er theke better phone, ami kinte cai.', {'entities': [(0, 10, 'model')]}), ('Redmi 9 unofficial ta hobe na ?', {'entities': [(0, 7, 'model')]}), ('Mi 11 lite EMI nete caile ki nite parbo...?', {'entities': [(0, 10, 'model')]}), ('Redmi Note 9 pro available? And price?', {'entities': [(0, 11, 'model')]}), ('Samsung Galaxy A52 available???', {'entities': [(8, 17, 'model')]}), ('Samsung Galaxy A32 ki ki color available?', {'entities': [(8, 17, 'model')]}), ('redmi k40 ase ki?', {'entities': [(0, 9, 'model')]}), ('oneplus nord 8/128 price koto', {'entities': [(0, 12, 'model')]}), ('redmi Note 10 plus ta koto?', {'entities': [(0, 11, 'model')]}), ('redmi Note 10 pro 6/128, Official available & Prize koto?', {'entities': [(0, 11, 'model')]}), ('poco f3 8/256 availabe ase ?', {'entities': [(0, 7, 'model')]}), ('xiaomi redmi redmi Note 10 Pro Max ??', {'entities': [(13, 24, 'model')]}), ('Mi 11 lite 4g naki 5g variant??', {'entities': [(0, 10, 'model')]}), ('Poco F3 ase?', {'entities': [(0, 7, 'model')]}), ('redmi k40 update price?', {'entities': [(0, 9, 'model')]}), ('Poco M3 6/128 hobe?', {'entities': [(0, 7, 'model')]}), ('Vai redmi k40  aca?', {'entities': [(4, 13, 'model')]}), ('Mi 11 lite eta ki 4g na 5g??', {'entities': [(0, 10, 'model')]}), ('redmi Note 10 pro (unf) avaiable??', {'entities': [(0, 11, 'model')]}), ('Poco m2 pro unofficial available ase?', {'entities': [(0, 11, 'model')]}), ('Narzo 20 available?', {'entities': [(0, 8, 'model')]}), ('Redmi note 8 à¦†à¦¾à¦›à§‡', {'entities': [(0, 11, 'model')]}), ('Poco x3 8-128 ache?', {'entities': [(0, 7, 'model')]}), ('xiaomi redmi redmi Note 10 (6+128) official pawa jabe?', {'entities': [(13, 24, 'model')]}), ('is pixel 4a available?? price?? might buy it today...', {'entities': [(3, 8, 'model')]}), ('redmi Note 10 Pro (Indian Variant) 8GB/128GB available??', {'entities': [(0, 11, 'model')]}), ('Mi 11 lite 8/128 yellow colour ki hobea?', {'entities': [(0, 10, 'model')]}), ('Poco x3 pro 6/128 available ?', {'entities': [(0, 7, 'model')]}), ('Need mi 11 lite 5g', {'entities': [(5, 15, 'model')]}), ('Vai redmi Note 10 koto unofficial', {'entities': [(4, 15, 'model')]}), ('Redmi note 9 pro 6gb sell korte chai official warranty gadget and gear theke nea', {'entities': [(0, 11, 'model')]}), ('iPhone X price', {'entities': [(0, 8, 'model')]}), ('Vaiya mate 30 pro 5g ta lagbe amar.', {'entities': [(6, 13, 'model')]}), ('Vaiya mate 30 pro 5g  ta ku ache..?', {'entities': [(6, 13, 'model')]}), ('Vaiya mate 30 pro 5g phone ta amar lagbei.', {'entities': [(6, 13, 'model')]}), ('Do you have oneplus 7pro 6/128?', {'entities': [(12, 21, 'model')]}), ('OnePlus 6 lagbe jodi 6 na thake tahole 7 lagbe.?', {'entities': [(0, 9, 'model')]}), ('Vaiya, mate 30 pro er price koto?', {'entities': [(7, 14, 'model')]}), ('Mate 30 pro offer price koto vaiya?', {'entities': [(0, 7, 'model')]}), ('iphone xs used price koto??', {'entities': [(0, 8, 'model')]}), ('iphone xs used price koto vaiya?', {'entities': [(0, 8, 'model')]}), ('Vai Realme 7pro & Realme 8pro konta best??', {'entities': [(18, 26, 'model')]}), ('Vai realme 7pro & Realme 8pro konta best??', {'entities': [(18, 26, 'model')]}), ('Vivo v20pro Akdhum fresh .Box Nai', {'entities': [(0, 8, 'model')]}), ('Redmi note 9pro price', {'entities': [(0, 11, 'model')]}), ('Vivo X60 Pro Lagbe', {'entities': [(0, 7, 'model')]}), ('Vivo X60 Pro...', {'entities': [(0, 7, 'model')]}), ('Need Vivo X60 Pro', {'entities': [(5, 12, 'model')]}), ('Galaxy A51', {'entities': [(0, 9, 'model')]}), ('Poco X3 sell', {'entities': [(0, 7, 'model')]}), ('Google pixel 4a 5g last à¦•à¦¤ à¦ªà¦°à§\x8dà¦¬à§‡?', {'entities': [(7, 12, 'model')]}), ('Bhai redmi Note 10 er price ta koto', {'entities': [(5, 16, 'model')]}), ('Oppo reno 5 price plz !', {'entities': [(0, 9, 'model')]}), ('Vai Need iPhone 11promax?', {'entities': [(9, 18, 'model')]}), ('Poco F3 available ekhon?', {'entities': [(0, 7, 'model')]}), ('OPPO RENO NEW Price koto?', {'entities': [(0, 9, 'model')]}), ('Vai Oppo Reno 5 new official price koto porbe?', {'entities': [(4, 13, 'model')]}), ('IPhone 7 silver edition ta hbe??', {'entities': [(0, 8, 'model')]}), ('samsung redmi Note 10 plas', {'entities': [(8, 19, 'model')]}), ('Vai oneplus 6t used ache', {'entities': [(4, 13, 'model')]}), ('Samsung Galaxy redmi Note 10+ 12gb 256 GB koto tk', {'entities': [(15, 26, 'model')]}), ('Vai realme 6 used price koto??', {'entities': [(4, 12, 'model')]}), ('Vai poco f3 er prize koto ekn', {'entities': [(4, 11, 'model')]}), ('Realme 7i', {'entities': [(0, 9, 'model')]}), ('Vai realme 8 ar price?', {'entities': [(4, 12, 'model')]}), ('Need Iphone 11pro max price?', {'entities': [(5, 14, 'model')]}), ('Realme X2 pro price??', {'entities': [(0, 8, 'model')]}), ('redmi Note 10 price', {'entities': [(0, 11, 'model')]}), ('Oneplus 7t ki ache?', {'entities': [(0, 9, 'model')]}), ('Vai redmi s2 price', {'entities': [(4, 12, 'model')]}), ('OPPO f17 asa ki?', {'entities': [(0, 7, 'model')]}), ('Oneplus 7t available bro?', {'entities': [(0, 9, 'model')]}), ('vaiya iphone 11 slim box koto ?', {'entities': [(6, 15, 'model')]}), ('vaiya iphone 7 koto ??', {'entities': [(6, 14, 'model')]}), ('Google Pixel 4 XL 128 GB available??', {'entities': [(7, 12, 'model')]}), ('Bai realme xt amar lagbo ace', {'entities': [(4, 12, 'model')]}), ('Poco x3 nfc', {'entities': [(0, 11, 'model')]}), ('Oppo reno 2z price', {'entities': [(0, 9, 'model')]}), ('Vai Ami Vivo V20 pro set ta cell kurty Chai .akhun fresh  ktu diven price', {'entities': [(13, 20, 'model')]}), ('poco f3 price koto??????', {'entities': [(0, 7, 'model')]}), ('Vai vivo v15pro price plz', {'entities': [(4, 11, 'model')]}), ('Brother Pixel 4 XL 128 GB available??', {'entities': [(8, 13, 'model')]}), ('Oppo reno 2z full box price koto?', {'entities': [(0, 9, 'model')]}), ('iPhone xr ace ki', {'entities': [(0, 8, 'model')]}), ('kmn acen vai oppo reno 5 diye dekci', {'entities': [(13, 22, 'model')]}), ('Oneplus 7t ase', {'entities': [(0, 9, 'model')]}), ('Iphone xr er price koto', {'entities': [(0, 8, 'model')]}), ('Realme 7i ace vaiya', {'entities': [(0, 9, 'model')]}), ('Remdi redmi Note 10 price 6/128 price?', {'entities': [(6, 17, 'model')]}), ('Realme x2 available?', {'entities': [(0, 8, 'model')]}), ('Vaiya Iphone 12 series hobe?', {'entities': [(6, 15, 'model')]}), ('oneplus 8t price', {'entities': [(0, 9, 'model')]}), ('My need pixel 5 used phone', {'entities': [(8, 13, 'model')]}), ('Redmi note7', {'entities': [(3, 10, 'model')]}), ('Samsung Galaxy S9+ purple lagto', {'entities': [(8, 17, 'model')]}), ('galaxy S10 lite 8/512 Available???', {'entities': [(0, 9, 'model')]}), ('iPhone 8plus ase 256gb', {'entities': [(0, 8, 'model')]}), ('Poco f3 asa ki', {'entities': [(0, 7, 'model')]}), ('Vaiya oppo f17 pro exchange kore realme 8 pro used ki nite parbo...?', {'entities': [(6, 13, 'model')]}), ('iphone 11 pro max', {'entities': [(0, 9, 'model')]}), ('1month use korsi REDMI NOTE 10 4/64 indian global. Kine chilam 17K diye... akhon sell dile koto pabo?', {'entities': [(17, 28, 'model')]}), ('Oneplus 8 pro 12/256GB with original charger sell korbo. Price koto pabo? Paper nai Kuwait theke aseche.', {'entities': [(0, 9, 'model')]}), ('Realme c3 4/64 baa 3/32 hobe', {'entities': [(0, 9, 'model')]}), ('Poco x3 price', {'entities': [(0, 7, 'model')]}), ('Vaiya oppo f17 pro exchange kore realme 8 Pro used mobile nite parbo ki.....?', {'entities': [(6, 13, 'model')]}), ('Realme c3 ase 4/64 baa 3/32', {'entities': [(0, 9, 'model')]}), ('Redmi 10 pro kmn??', {'entities': [(0, 7, 'model')]}), ('Samsung galaxy f62 available', {'entities': [(8, 18, 'model')]}), ('Xiaomi mi 11 ultra 12/512 available??  And price??', {'entities': [(0, 11, 'model')]}), ('Galaxy F62 used phone available..', {'entities': [(0, 10, 'model')]}), ('iPhone X 64gb price koto', {'entities': [(0, 8, 'model')]}), ('Poco x3 pro bolen', {'entities': [(0, 7, 'model')]}), ('Poco x3 pro price ta bolen vaiya', {'entities': [(0, 7, 'model')]}), ('Samsung galaxy f62 available ase??', {'entities': [(8, 18, 'model')]}), ('Pixel 4A hbe ki?', {'entities': [(0, 5, 'model')]}), ('Oppo reno 5 second hand available...', {'entities': [(0, 9, 'model')]}), ('Poco x3pro pao a jabe', {'entities': [(0, 7, 'model')]}), ('Oneplus nord n10 used price plz', {'entities': [(0, 12, 'model')]}), ('poco x3 pro official international global er price kto?', {'entities': [(0, 7, 'model')]}), ('Poco x3 ctg te ki pawa jabe?', {'entities': [(0, 7, 'model')]}), ('ময়মনসিংহ কি শাখা আছে? Iphone 12 Pro Max 256 Pacific Blue price please? Official and unofficial both price.', {'entities': [(22, 31, 'model')]}), ('Oneplus 8 pro 12/256 gp sell korbo. Price koto pabo? Paper nai Kuwait theke aseche.', {'entities': [(0, 9, 'model')]}), ('Poco x3 er price koto new and used?', {'entities': [(0, 7, 'model')]}), ('Realme 8 Pro Price..', {'entities': [(0, 8, 'model')]}), ('Iphone 8+,xr price', {'entities': [(0, 8, 'model')]}), ('Vaiya redmi k40 kobe pawa jete pare??', {'entities': [(6, 15, 'model')]}), ('iphone x available??', {'entities': [(0, 8, 'model')]}), ('Poco f3 price.?', {'entities': [(0, 7, 'model')]}), ('Iphone 8+ price', {'entities': [(0, 8, 'model')]}), ('Redmi note 9 64 gb without box daam koto porbe', {'entities': [(0, 11, 'model')]}), ('Google pixel 5 price', {'entities': [(7, 12, 'model')]}), ('bro oneplus 8t er price ta 8/128', {'entities': [(4, 13, 'model')]}), ('ভাই iphone 8+ acheee???', {'entities': [(4, 12, 'model')]}), ('Poco f3 available???', {'entities': [(0, 7, 'model')]}), ('I have need Samsung a52/ pixel 4a brand new phone.', {'entities': [(25, 30, 'model')]}), ('Iphone 11 64 GB japan & USA inactive slim box er current price ?', {'entities': [(0, 9, 'model')]}), ('Apple  iPhone 11 used but fresh condition KTO viaya', {'entities': [(7, 16, 'model')]}), ('OnePlus 8 pro ase ki vaia ???', {'entities': [(0, 9, 'model')]}), ('iPhone 12 pro earphone home delivery hobe sreepur gazipur', {'entities': [(0, 9, 'model')]}), ('Xiaomi redmi note 9 4/64 price koto??? Used', {'entities': [(7, 18, 'model')]}), ('Samsung galaxy a72 8/256 price?', {'entities': [(8, 17, 'model')]}), ('vaia poco m2 pro 6/64 ta koto month used??', {'entities': [(5, 16, 'model')]}), ('Iphone 12 pro er real earphone home delivery hobe Gazipur sreepur', {'entities': [(0, 9, 'model')]}), ('Samsung galaxy a52 need', {'entities': [(8, 17, 'model')]}), ('iPhone 12 mini ki hobe', {'entities': [(0, 9, 'model')]}), ('poco x3 pro lagbe amr', {'entities': [(0, 7, 'model')]}), ('Ki obostha vai Galaxy M62 ase naki ?', {'entities': [(15, 25, 'model')]}), ('Hi Galaxy A02 ase ?', {'entities': [(3, 13, 'model')]}), ('realme x2 koto din use?', {'entities': [(0, 8, 'model')]}), ('Redmi Note 9 s ta lagbe 6)128', {'entities': [(0, 11, 'model')]}), ('call dile bolen Redmi 9 available nai unofficial abr list e diye rakhsen price 11999', {'entities': [(16, 23, 'model')]}), ('Home delivery charge Kemon? Ekta iphone xr lagbe', {'entities': [(33, 41, 'model')]}), ('Mi 10 ultra koto???', {'entities': [(0, 11, 'model')]}), ('Redmi note 10 6/128 achy nh?', {'entities': [(0, 11, 'model')]}), ('redmi note 10 max used hove?', {'entities': [(0, 11, 'model')]}), ('IPhone 11, 128 gb nei?', {'entities': [(0, 9, 'model')]}), ('galaxy S21 Ultra snapdragon edition aceh?', {'entities': [(0, 9, 'model')]}), ('Modaret condition mane ki iphone 11 er', {'entities': [(26, 35, 'model')]}), ('gusti chudi shawwar phone er. Iphone 8 er warranty den nai', {'entities': [(30, 38, 'model')]}), ('iphone x 80+ bh and original charger hbe?', {'entities': [(0, 8, 'model')]}), ('galaxy S21 + official ইনট্যাক্ট নেই?', {'entities': [(0, 9, 'model')]}), ('Iphone 11 64 gb BH koto%?  Nite chai.', {'entities': [(0, 9, 'model')]}), ('galaxy S10 emi a daya jaba ...amar kasa 25k asa', {'entities': [(0, 9, 'model')]}), ('Oppo reno 5 price koto vai.?', {'entities': [(0, 9, 'model')]}), ('vai iphone x ase used ?', {'entities': [(4, 12, 'model')]}), ('iphone 12 pro 256gb koto porbe ?', {'entities': [(0, 9, 'model')]}), ('Need Redmi Note 10 Pro 6/128', {'entities': [(5, 16, 'model')]}), ('Redmi K20 pro still Available?', {'entities': [(0, 9, 'model')]}), ('Redmi 10x 4g available?', {'entities': [(0, 7, 'model')]}), ('Poco x3 pro er dam koto', {'entities': [(0, 7, 'model')]}), ('iphone 7 plus er bh koto?', {'entities': [(0, 13, 'model')]}), ('samsung s10 plus with box 34000??', {'entities': [(9, 16, 'model')]}), ('iPhone 11 64 gb', {'entities': [(0, 9, 'model')]}), ('iphone 7 plus BH?', {'entities': [(0, 13, 'model')]}), ('Honor play / huawei honor play player edition ta lagto', {'entities': [(0, 10, 'model')]}), ('IPhone 7 plus ar battery health koto?', {'entities': [(0, 13, 'model')]}), ('iphone 11 pro max..avaiable nai?', {'entities': [(0, 9, 'model')]}), ('Iphone 11 with box er mane ki box + charger + headphone?', {'entities': [(0, 9, 'model')]}), ('Redmi note 8 128 gb koto...?', {'entities': [(0, 11, 'model')]}), ('iPhone 12- 128gb tar battery health koto', {'entities': [(0, 9, 'model')]}), ('Need realme narzo 20', {'entities': [(5, 17, 'model')]}), ('Redmi note 7 pavo', {'entities': [(0, 11, 'model')]}), ('Iphone 7 plus Offcial nake', {'entities': [(0, 13, 'model')]}), ('iphone 7 plus er bettary health koto', {'entities': [(0, 13, 'model')]}), ('Redmi Note 9s available?', {'entities': [(0, 11, 'model')]}), ('huawei P30 pro 40k te', {'entities': [(0, 10, 'model')]}), ('Realme 7 pro is up for sale', {'entities': [(0, 9, 'model')]}), ('iphone 8 plus need', {'entities': [(0, 8, 'model')]}), ('Xchange my mi 9t pro with note 10 pro max.... Full box with cash memo...', {'entities': [(11, 20, 'model')]}), ('Realme 5 pro price ki fxd', {'entities': [(0, 8, 'model')]}), ('Realme 8.', {'entities': [(0, 8, 'model')]}), ('Realme 2 pro ki full brand new?', {'entities': [(0, 8, 'model')]}), ('Realme x2 pro red brick edition er condition kmn?', {'entities': [(0, 8, 'model')]}), ('Realme X2 pro', {'entities': [(0, 8, 'model')]}), ('Bhai realme X2pro ta ki ache? 8/128...?', {'entities': [(5, 13, 'model')]}), ('realme x2 pro gray colour hobe.?', {'entities': [(0, 8, 'model')]}), ('Realme 8 available', {'entities': [(0, 8, 'model')]}), ('Realme 8 inteck ace & prize', {'entities': [(0, 8, 'model')]}), ('Realme 7 Pro available???', {'entities': [(0, 9, 'model')]}), ('Realme 6i (indian) available?', {'entities': [(0, 8, 'model')]}), ('Realme 8 lagbe intek price', {'entities': [(0, 8, 'model')]}), ('Realme c11 price ta sotik ar set ki originall', {'entities': [(0, 9, 'model')]}), ('Realme 8 ta amer lagbe', {'entities': [(0, 8, 'model')]}), ('Realme 25s ache?', {'entities': [(0, 8, 'model')]}), ('Realme 8 pro...ki color ?', {'entities': [(0, 8, 'model')]}), ('Realme 6 available????', {'entities': [(0, 8, 'model')]}), ('vai realme X', {'entities': [(4, 12, 'model')]}), ('R sylhet er shoeroom ee ki pabo realme 2 pro', {'entities': [(32, 40, 'model')]}), ('Realme GT Nai ????', {'entities': [(0, 9, 'model')]}), ('Realme c17 ta lagbe', {'entities': [(0, 9, 'model')]}), ('Realme c17 last price koto r booking korte koto dite hobe...', {'entities': [(0, 9, 'model')]}), ('Realme 8 pro আছে?', {'entities': [(0, 8, 'model')]}), ('Realme 8 pro kotodin warrenty ase?', {'entities': [(0, 8, 'model')]}), ('Realme 5pro আনুমানিক কত দিন used হয়েছে??', {'entities': [(0, 8, 'model')]}), ('Realme 5i available kemne??', {'entities': [(0, 8, 'model')]}), ('Realme narzo 20 box dabe na. Copy na ki', {'entities': [(0, 12, 'model')]}), ('Realme 8 used phone tah ki colour....', {'entities': [(0, 8, 'model')]}), ('Realme 8 brand new model koto ?', {'entities': [(0, 8, 'model')]}), ('I need realme c17 if available let me knw..thnx', {'entities': [(7, 16, 'model')]}), ('Narzo 20 ace...?', {'entities': [(0, 8, 'model')]}), ('Realme c12 lagbe amr ekta', {'entities': [(0, 9, 'model')]}), ('Iphone 11 128 gb price???', {'entities': [(0, 9, 'model')]}), ('iphone xs 64GB price', {'entities': [(0, 8, 'model')]}), ('Iphone xr price range...!', {'entities': [(0, 8, 'model')]}), ('Iphone x 64 silver price koto?', {'entities': [(0, 8, 'model')]}), ('IPhone x available?', {'entities': [(0, 8, 'model')]}), ('IPhone XR er price?', {'entities': [(0, 8, 'model')]}), ('Iphone xs gold 256 gb koto ?', {'entities': [(0, 8, 'model')]}), ('Iphone x', {'entities': [(0, 8, 'model')]}), ('IPhone x black 128 gb price', {'entities': [(0, 8, 'model')]}), ('IPhone X(256gb) price???', {'entities': [(0, 8, 'model')]}), ('bhai iphone 7 plus', {'entities': [(5, 18, 'model')]}), ('iphone Xs max 256gb price? & xs max 64gb price???', {'entities': [(0, 8, 'model')]}), ('iphone x 64gb price?', {'entities': [(0, 8, 'model')]}), ('iphone Xr 128 gb price??', {'entities': [(0, 8, 'model')]}), ('iphone X  and XR 64gb price?', {'entities': [(0, 8, 'model')]}), ('iphone 8 plus price?', {'entities': [(0, 8, 'model')]}), ('iphone X max Price', {'entities': [(0, 8, 'model')]}), ('iphone 6s plus koto', {'entities': [(0, 14, 'model')]}), ('iphone 11 128 gb price', {'entities': [(0, 9, 'model')]}), ('iphone X max 256gold price', {'entities': [(0, 8, 'model')]}), ('iphone 6s price', {'entities': [(0, 9, 'model')]}), ('iphone XR 256gb black price pls', {'entities': [(0, 8, 'model')]}), ('iphone X 64gb', {'entities': [(0, 8, 'model')]}), ('Apple iphone xr price', {'entities': [(6, 14, 'model')]}), ('vai iphone xr er price koto', {'entities': [(4, 12, 'model')]}), ('iphone X price???', {'entities': [(0, 8, 'model')]}), ('Vaiya iphone x -64 gb er price ta koto', {'entities': [(6, 14, 'model')]}), ('iphone X 256 GB price ?', {'entities': [(0, 8, 'model')]}), ('iphone Xs max 256', {'entities': [(0, 8, 'model')]}), ('iphone X er dam koto', {'entities': [(0, 8, 'model')]}), ('iphone 7 plus 128 GB Price ?', {'entities': [(0, 13, 'model')]}), ('iphone xr 64gb price?', {'entities': [(0, 8, 'model')]}), ('iphone 7 asa?', {'entities': [(0, 8, 'model')]}), ('iphone 6s plus?', {'entities': [(0, 14, 'model')]}), ('iphone xr 64 price....??', {'entities': [(0, 8, 'model')]}), ('iphone 8 plus 64gb price?', {'entities': [(0, 8, 'model')]}), ('iphone XR 64 gb price?', {'entities': [(0, 8, 'model')]}), ('Oneplus 9  এটা আমি কিনবো01799177349', {'entities': [(0, 9, 'model')]}), ('Vy amr redmi note 8 lagbe', {'entities': [(7, 18, 'model')]}), ('Amar  redmi note 8 lagbe', {'entities': [(6, 17, 'model')]}), ('Redmi note 8 নেব মোবাঃ ০১৮৭২৯০৯৪৫১', {'entities': [(0, 11, 'model')]}), ('Radmi note 8 coll me 01924456080', {'entities': [(3, 10, 'model')]}), ('iPhone 11 pro লাগবে 01762403190', {'entities': [(0, 9, 'model')]}), ('IPhone 11 Pro lagbe, call me anytime 01317176262', {'entities': [(0, 9, 'model')]}), ('Redmi note 8 লাগবে', {'entities': [(0, 11, 'model')]}), ('Redmi note 9ar price 3099tk na ki', {'entities': [(0, 11, 'model')]}), ('Redmi Note 9 lagba hmoe delivery charge koto', {'entities': [(0, 11, 'model')]}), ('Vaia amar redmi note8lagbe', {'entities': [(13, 20, 'model')]}), ('Redmi note 9 amar dorkar', {'entities': [(0, 11, 'model')]}), ('vai Redmi note 8 ami nite chai ki vabe  odar korbo   plz call me 0181488614', {'entities': [(4, 15, 'model')]}), ('redmi 8 lagbo amar', {'entities': [(0, 7, 'model')]}), ('Amar Redmi note 9 lagbe', {'entities': [(5, 16, 'model')]}), ('Redmi Note 8 কিনবে', {'entities': [(0, 11, 'model')]}), ('Amar redmi note 9 lagbe', {'entities': [(5, 16, 'model')]}), ('amar iphone 11 pro lagve plz call me 01754888159', {'entities': [(5, 14, 'model')]}), ('Redmi note 8 nebo 01314797849', {'entities': [(0, 11, 'model')]}), ('vaiya ami redmi note 9 nibo..01885742077 please call me', {'entities': [(10, 21, 'model')]}), ('Amar redmi note 9 lagbe ok', {'entities': [(5, 16, 'model')]}), ('iphone 11 pro nite chai', {'entities': [(0, 9, 'model')]}), ('Vai Amar readmi note 11 ultra lagbe koto dam', {'entities': [(13, 20, 'model')]}), ('Vai amak galaxy s10 lagbe kivabe  nibo', {'entities': [(9, 18, 'model')]}), ('redmi note 8 ta lagbe??', {'entities': [(0, 11, 'model')]}), ('iphone 11 lagbe bhaiya ami kibabe nibo please call me 01772768783', {'entities': [(0, 9, 'model')]}), ('iphone 11 pro koto hole kena jabe', {'entities': [(0, 9, 'model')]}), ('vivo V15 মুবাইল ফুন লাগবে', {'entities': [(0, 7, 'model')]}), ('ami oneplus 9 nibo', {'entities': [(4, 13, 'model')]}), ('Redmi Note এটা আমার লাগবে', {'entities': [(0, 11, 'model')]}), ('Vhi amr IPhone 12 lgbo', {'entities': [(8, 17, 'model')]}), ('vivo v17 amer lagbe ki ba nibo cool me', {'entities': [(0, 7, 'model')]}), ('Redmi Note 9 1,500Tk', {'entities': [(0, 11, 'model')]}), ('Vi amar redmi note 8 lagbe kivave ki korbo', {'entities': [(8, 19, 'model')]}), ('redmi note 9 lagbe', {'entities': [(0, 11, 'model')]}), ('Redmi note 8নিমু', {'entities': [(0, 11, 'model')]}), ('iphone 12 pro ase', {'entities': [(0, 9, 'model')]}), ('Realme 5i cash add korbo', {'entities': [(0, 8, 'model')]}), ('iPhone 6s+', {'entities': [(0, 9, 'model')]}), ('Vai poco m3', {'entities': [(4, 11, 'model')]}), ('Exchange xiaomi note 8', {'entities': [(13, 20, 'model')]}), ('Redmi note 9 prime 1 month used vaia', {'entities': [(0, 11, 'model')]}), ('Redmi note 7', {'entities': [(0, 11, 'model')]}), ('Realme 6i', {'entities': [(0, 8, 'model')]}), ('Redmi note 8 4/64.... 4 month use.', {'entities': [(0, 11, 'model')]}), ('Realme 3pro full fresh', {'entities': [(0, 8, 'model')]}), ('Redmi 9 pawar 4/64', {'entities': [(0, 7, 'model')]}), ('iPhone 6s+', {'entities': [(0, 9, 'model')]}), ('redmi note 8', {'entities': [(0, 11, 'model')]}), ('আমি readmi note nibo', {'entities': [(8, 15, 'model')]}), ('Ami redmi note 8 nemo', {'entities': [(4, 15, 'model')]}), ('Nokia 10 plus lagbo', {'entities': [(0, 7, 'model')]}), ('Vaia amar Nokia 10 plus', {'entities': [(10, 17, 'model')]}), ('AMR redmi note8 phoneta lagbe ata kokhon pabo', {'entities': [(7, 14, 'model')]}), ('ami galaxy s7 ta nibo atar dam koto', {'entities': [(4, 13, 'model')]}), ('Amr nokia 10 plus ta lagbe', {'entities': [(4, 11, 'model')]}), ('ami nokia 10 plus nibo', {'entities': [(4, 11, 'model')]}), ('একটা realme x8 mobile কত টাকা', {'entities': [(5, 13, 'model')]}), ('আমি নিতে চাই কিভাবে নিবো Redmi Note 8', {'entities': [(25, 36, 'model')]}), ('iphone x3 nibo.kivabe nite hobe', {'entities': [(0, 8, 'model')]}), ('Ami redmi note nibo', {'entities': [(4, 15, 'model')]}), ('Oppo F19 Pro  এর দাম  কত টাকা?', {'entities': [(0, 7, 'model')]}), ('Redmi Note 9 Pro  Phone  er amount  koto.', {'entities': [(0, 11, 'model')]}), ('ভাই nokia 7. 2  সেটের দাম কত টাকা হবে', {'entities': [(4, 11, 'model')]}), ('I need 1pc Nokia 10 plus my number 01303939935', {'entities': [(11, 18, 'model')]}), ('Nokia 10 plus nite chai', {'entities': [(0, 7, 'model')]}), ('ami nite chi nokia 10plus', {'entities': [(13, 20, 'model')]}), ('ভাই এতো কম টাকায় এতো দামি ফোন সত্যি কি সম্ভব!!! হলে আমি nokia 10 pluse টা নিতাম। ধন্যবাদ', {'entities': [(56, 63, 'model')]}), ('iPhone x3 price koto', {'entities': [(0, 8, 'model')]}), ('Ami Nokia 10 plus neta chai', {'entities': [(4, 11, 'model')]}), ('Oppo f19 pro', {'entities': [(0, 7, 'model')]}), ('Redmi note home delivery dao', {'entities': [(0, 11, 'model')]}), ('Redmi Note 8', {'entities': [(0, 11, 'model')]}), ('Nokia 7 Plus 2999', {'entities': [(0, 7, 'model')]}), ('Xiaomi Redmi Note 10 available? and eitar price koto?', {'entities': [(7, 18, 'model')]}), ('Redmi note 9 unofficial ace', {'entities': [(0, 11, 'model')]}), ('redmi note 9 pro max available?', {'entities': [(0, 11, 'model')]}), ('Mi11x and poco f3 ki akdom same?', {'entities': [(10, 17, 'model')]}), ('ভাই Redmi note 10(4GB/64GB) PRICE???', {'entities': [(4, 15, 'model')]}), ('Bro ami order form fill up korchi, Redmi 9 power 6/128 er jonno. Amake ki call deya hobe/', {'entities': [(35, 42, 'model')]}), ('redmi 9 pawa jabe 4/64 15000', {'entities': [(0, 7, 'model')]}), ('Poco f3. 8+256... Ki BTRC database a ase apnader kase jeigula ase... Amar lagbe jodi BTRC database base a thake tahole nebo', {'entities': [(0, 7, 'model')]}), ('Poco x3 ki available?', {'entities': [(0, 7, 'model')]}), ('Poco x3 pro 8/256 unofficial price', {'entities': [(0, 7, 'model')]}), ('Poco x3 pro unofficial price koto akhon????', {'entities': [(0, 7, 'model')]}), ('Realme 8 ভালো হবে নাকি Redmi Note 10s ভালো হবে? দয়া করে জানাবেন।', {'entities': [(0, 8, 'model')]}), ('Redmi Note 10 Int koto?', {'entities': [(0, 11, 'model')]}), ('Iphone 12 128gb USA', {'entities': [(0, 9, 'model')]}), ('Redmi note 9 pro 4/64 price', {'entities': [(0, 11, 'model')]}), ('POCO M3 6/128 & 4/128 PRICE KOTO UNOFFICIAL?', {'entities': [(0, 7, 'model')]}), ('Redmi note 9', {'entities': [(0, 11, 'model')]}), ('Poco x3 pro all color availbe? 8/128', {'entities': [(0, 7, 'model')]}), ('Poco x3 pro 8/256 unofficial er price ta koto?', {'entities': [(0, 7, 'model')]}), ('Redmi note 10 pro price koto', {'entities': [(0, 11, 'model')]}), ('POCO X3 UNOFFICIAL PRICE KOTO?', {'entities': [(0, 7, 'model')]}), ('Readmi Note 10 pro max hove.... unofficial 8/128', {'entities': [(4, 11, 'model')]}), ('Vai poco x3 pro indian global official price?', {'entities': [(4, 11, 'model')]}), ('Poco m2 pro official  price Koto', {'entities': [(0, 11, 'model')]}), ('oneplus nord ce 5g price?', {'entities': [(0, 12, 'model')]}), ('Redmi note 10 0fficial koto???', {'entities': [(0, 11, 'model')]}), ('poco x3 Pro', {'entities': [(0, 7, 'model')]}), ('Xiaomi Poco F3', {'entities': [(7, 14, 'model')]}), ('Redmi Note 10 pro max hove.... unofficial 8/128', {'entities': [(0, 11, 'model')]}), ('redmi Note 8 pro price???', {'entities': [(0, 11, 'model')]}), ('Galaxy s7 edge woder Korte chai', {'entities': [(0, 9, 'model')]}), ('redmi note 10 koto hobi', {'entities': [(0, 11, 'model')]}), ('nokia 10 plus lagbokmne order kormo', {'entities': [(0, 7, 'model')]}), ('আমি   oppo f19 pro নিগে চাই', {'entities': [(6, 13, 'model')]}), ('Galaxy S7 edge  copy      না কি? আমার একটি সেট লাগবে।', {'entities': [(0, 9, 'model')]}), ('nokia 7 plus ar iphone ta lagbe...', {'entities': [(0, 7, 'model')]}), ('Nokia 10 plus  নিতে চাই', {'entities': [(0, 7, 'model')]}), ('Waiting for redmi k40 6/128', {'entities': [(12, 21, 'model')]}), ('Redmi note10 6/128(21999) note10 pro (23500) what is different between 2', {'entities': [(3, 10, 'model')]}), ('POCO X3 Indian available??', {'entities': [(0, 7, 'model')]}), ('iPhone 12 mini which country? iPhone SE2 available?', {'entities': [(30, 39, 'model')]}), ('Poco x3 pro 6/128 international global price Please', {'entities': [(0, 7, 'model')]}), ('Realme 8 pro not available?', {'entities': [(0, 8, 'model')]}), ('redmi k40 white color available ??', {'entities': [(0, 9, 'model')]}), ('Mi 11 lite ...is it 5G....???', {'entities': [(0, 10, 'model')]}), ('Redmi note 9 pro (4/64) available ase...???', {'entities': [(0, 11, 'model')]}), ('Realme 8 pro official available?', {'entities': [(0, 8, 'model')]}), ('Redmi note 10 pro price?', {'entities': [(0, 11, 'model')]}), ('Poco X3 available?', {'entities': [(0, 7, 'model')]}), ('In Google Pixel 4A, Which variant you are selling?', {'entities': [(10, 15, 'model')]}), ('iPhone 12 Pro Max 256GB Dual (Active) ki available?', {'entities': [(0, 9, 'model')]}), ('Realme C25 available?', {'entities': [(0, 9, 'model')]}), ('Xiaomi note 9 pro 4/64 price?', {'entities': [(4, 11, 'model')]}), ('redmi 10x chinese version e kon processor?', {'entities': [(0, 7, 'model')]}), ('Redmi Note 10 Pro (Int Global) Official ta ki available?', {'entities': [(0, 11, 'model')]}), ('Poco m2 pro (6/64)ki ase prise koto', {'entities': [(0, 11, 'model')]}), ('Redmi 10x ki available??', {'entities': [(0, 7, 'model')]}), ('mi 11 lite price koto', {'entities': [(0, 10, 'model')]}), ('Redmi 10X white color (4/128) Factory Intact Sealed Box 14K hole 1 pcs order korar ecche cilo...', {'entities': [(0, 7, 'model')]}), ('kalka kokhon shop oipen thakba?? redmi note 10 pro available???', {'entities': [(33, 44, 'model')]}), ('Vai POCO M2 pro kobe available?', {'entities': [(4, 15, 'model')]}), ('Mi 10 lite ki asbena vai', {'entities': [(0, 10, 'model')]}), ('ভাই redmi 9 unofficial হবে? হলে দামটা জানাবেন প্লিজ।', {'entities': [(4, 11, 'model')]}), ('Redmi note 10 4/64  price  ki ekhono 16500tkai?', {'entities': [(0, 11, 'model')]}), ('Redmi K40Pro te playstore & YouTube  direct cholbe?', {'entities': [(0, 9, 'model')]}), ('poco m2 er jnno 18w er fast charger  ki available?  r price koto?', {'entities': [(0, 7, 'model')]}), ('vai redmi note 10 pro 6/128 hoba? & price koto. janaben pls.', {'entities': [(4, 15, 'model')]}), ('Realme 8 ar price koto?', {'entities': [(0, 8, 'model')]}), ('Mi 11 lite ki 5g?', {'entities': [(0, 10, 'model')]}), ('Redmi note 10 pro official hobe ki', {'entities': [(0, 11, 'model')]}), ('Redmi note 10 pro international 6/128 tar price koto?  plz janaben', {'entities': [(0, 11, 'model')]}), ('Redmi k20 6/128 price? Kew janle comment kore janan', {'entities': [(0, 9, 'model')]}), ('vai poco f3 ase??', {'entities': [(4, 11, 'model')]}), ('Redmi k30 6/128 aca apneder kasa?', {'entities': [(0, 9, 'model')]}), ('Poco x3 pro 6/128 international ta nai???', {'entities': [(0, 7, 'model')]}), ('poco x3 pro 6/128 international global price please??', {'entities': [(0, 7, 'model')]}), ('Poco X3 pro unofficial kto 6:128 gb', {'entities': [(0, 7, 'model')]}), ('Redmi k40 8-128 variant available?', {'entities': [(0, 9, 'model')]}), ('poco X3 NFC Indian/', {'entities': [(0, 11, 'model')]}), ('iphone 12 purple coloure  ase ki', {'entities': [(0, 9, 'model')]}), ('Poco x3 nfc 6/128 available?', {'entities': [(0, 11, 'model')]}), ('want to exchange my s9+ single sim European variant 128 gb with ur pixel 4a 128 gb. if i exchange how much cash would be add??', {'entities': [(67, 72, 'model')]}), ('Realme 8  Is it available ?  Price?', {'entities': [(0, 8, 'model')]}), ('Why we pick you when others giving iphone 11 usa on 64,500 taka with 100% authentic and inactive?', {'entities': [(35, 44, 'model')]}), ('HUAWEI mate 40 pro  Is it possible!  If possible, price please.', {'entities': [(7, 14, 'model')]}), ('redmi note 10 pro 64mp not available ??', {'entities': [(0, 11, 'model')]}), ('Redmi note 10 pro international price please 6/128', {'entities': [(0, 11, 'model')]}), ('Realmi 8 pro ase official', {'entities': [(4, 12, 'model')]}), ('Redmi K40 8 256 available', {'entities': [(0, 9, 'model')]}), ('black shark k40 series', {'entities': [(0, 11, 'model')]}), ('Pixel 4a dam koman', {'entities': [(0, 5, 'model')]}), ('Samsung galaxy S20 fe 4g snapdragon varrient ta ki available hbe? And hole price?', {'entities': [(8, 17, 'model')]}), ('Vai brand new Oneplus 8 pro (12/256) patuakhali te shunderban curiyar shoho koto tk porbe...', {'entities': [(14, 23, 'model')]}), ('Vivo x60 pro koto taka', {'entities': [(0, 7, 'model')]}), ('Oneplus 8 pro 12/256 blue nite chai vai..', {'entities': [(0, 9, 'model')]}), ('Vai ami koyekbar phn deyechi but apnader network busy ashe..... ami oneplus 8 pro nibo ajk', {'entities': [(68, 77, 'model')]}), ('Vhai oneplus 8 4G bujhlamna!', {'entities': [(5, 14, 'model')]}), ('Iphone 11 128gb japan eita ki active naki inactive?', {'entities': [(0, 9, 'model')]}), ('Ipad pro 12.9 inch 128 gb etay EMI available?', {'entities': [(0, 14, 'model')]}), ('Redmi note 9s diye one plus 8T neoa possible?', {'entities': [(0, 11, 'model')]}), ('realme 7 6/64 price?', {'entities': [(0, 9, 'model')]}), ('Poco m2 pro ki official', {'entities': [(0, 11, 'model')]}), ('vai poco x3 6/128 official koto dam??', {'entities': [(4, 11, 'model')]}), ('Vai iphone 12 pro max dual sim koto hobe??', {'entities': [(4, 13, 'model')]}), ('Poco m2 reloaded phone er price', {'entities': [(0, 7, 'model')]}), ('iPhone 12 mini ..Eid er ag porjonto available hobe?', {'entities': [(0, 9, 'model')]}), ('poco m2 pro 6/64 available?', {'entities': [(0, 11, 'model')]}), ('Samsung Galaxy A52 এর দাম দিয়ে রেখেছেন, কিন্তু আপনাদের শপ এ ফোন দিলাম বোল্লেন নাই!!', {'entities': [(8, 17, 'model')]}), ('Iphone 12. Pro max ki 112k ekhn intact usa 256 gb version??', {'entities': [(0, 9, 'model')]}), ('Vai apnader kase ki redmi note 10pro max available??', {'entities': [(20, 31, 'model')]}), ('Redmi note 10 4/64 স্টকে এভেইলাবল??  ১৬৫০০ বাজেটে আর কি কি বিকল্প আছে?', {'entities': [(0, 11, 'model')]}), ('Bhai, Poco M2 Pro 6/64 er price koto? Kon colour ta available???', {'entities': [(6, 17, 'model')]}), ('Iphone xs er price kmn?', {'entities': [(0, 8, 'model')]}), ('Realme x3 superzoom?', {'entities': [(0, 8, 'model')]}), ('oppo A92 sell kora jabe?', {'entities': [(0, 8, 'model')]}), ('iPhone xr kto?', {'entities': [(0, 8, 'model')]}), ('Redmi note 9 pro ki official?', {'entities': [(0, 11, 'model')]}), ('Iphone 12 . 128 GP USA version', {'entities': [(0, 9, 'model')]}), ('OnePlus 7 Pro Price ???', {'entities': [(0, 9, 'model')]}), ('Mi 11 lite 5g anen', {'entities': [(0, 10, 'model')]}), ('redmi k40 pro available?', {'entities': [(0, 9, 'model')]}), ('poco x3 (ind) ta kI 20k hbe na?', {'entities': [(0, 7, 'model')]}), ('Poco f3 available?', {'entities': [(0, 7, 'model')]}), ('Google pixel 4a, is it Indian or global???', {'entities': [(7, 12, 'model')]})]

# %%
TRAIN_DATA[5]
# Out:
# ('Nokia 10 plus  নিতে চাই', {'entities': [(0, 7, 'model')]})

# %%
ner.add_label(LABEL)
optimizer = nlp.resume_training(g=0)
move_names = list(ner.move_names)

# %%
import random
from spacy.util import minibatch, compounding
from pathlib import Path

# %%
pipe_exceptions = ["ner", "trf_wordpiecer", "trf_tok2vec"]
other_pipes = [pipe for pipe in nlp.pipe_names if pipe not in pipe_exceptions]

# %%
from spacy.util import minibatch, compounding
import random

# Begin training by disabling other pipeline components
with nlp.disable_pipes(*other_pipes) :

  sizes = compounding(1.0, 4.0, 1.001)
  # Training for 30 iterations     
  for itn in range(10):
    # shuffle examples before training
    random.shuffle(TRAIN_DATA)
    # batch up the examples using spaCy's minibatch
    batches = minibatch(TRAIN_DATA, size=sizes)
    # ictionary to store losses
    losses = {}
    for batch in batches:
      texts, annotations = zip(*batch)
      # Calling update() over the iteration
      nlp.update(texts, annotations, sgd=optimizer, drop=0.35, losses=losses)
      print("Losses", losses)
# Out:
# Losses {'ner': 8.26769711405359}
# Losses {'ner': 8.274695881489606}
# Losses {'ner': 9.770184273312452}
# Losses {'ner': 12.030514357812763}
# Losses {'ner': 14.348938110412373}
# Losses {'ner': 15.835072021795096}
# Losses {'ner': 16.238262619746386}
# Losses {'ner': 18.155915101913237}
# Losses {'ner': 22.720483757065935}
# Losses {'ner': 26.332933097951077}
# Losses {'ner': 30.498034849589338}
# Losses {'ner': 34.37957524584325}
# Losses {'ner': 36.16941807123563}
# Losses {'ner': 38.58327316833517}
# Losses {'ner': 43.51001596698394}
# Losses {'ner': 46.3928420533323}
# Losses {'ner': 50.86068338767497}
# Losses {'ner': 53.042467574392745}
# Losses {'ner': 61.73020282229278}
# Losses {'ner': 64.32284117049721}
# Losses {'ner': 65.6851895766891}
# Losses {'ner': 70.66515411062626}
# Losses {'ner': 70.66515411062626}
# Losses {'ner': 73.00122481190242}
# Losses {'ner': 79.29686377920784}
# Losses {'ner': 80.96355841734673}
# Losses {'ner': 88.74769127853045}
# ...

# %%
test_text = "vai iphone x available ase ?"
doc = nlp(test_text)
#print("entities", [(ent.text, ent.label_) for ent in doc.ents])
print("Entities in '%s'" % test_text)
for ent in doc.ents:
  print(ent)
#doc.ents[0]
# Out:
# Entities in 'vai iphone x available ase ?'

# %%
testset15 = ['Poco f3 ni?',
'poco x3 Ata ki made by India.....',
'redmi Note 10 4/64',
'waiting for iphone 12 pro max',
'iphone x 5G version?',
'Poco x3 pro int. Global available? Price?',
'oneplus 8 Official naki unofficial asbe....',
'R u bringing 4g or 5g iphone 12?',
'Redmi note 9 pro max prise koto..',
'poco x3 Price??',
'When come mi 11 and price',
'pixel 4 4G or 5G ? 5G hole amar ekta lagbei lagbe',
'poco x3 ind (6/128gb) unofficial available??',
'Price 25k we niche house neya jai..',
'Price 53k er moddhe galaxy a5 pawa jabe ?']

# %%
for x in testset15:
    test_text = str(x)
    doc = nlp(test_text)
    #print("entities", [(ent.text, ent.label_) for ent in doc.ents])
    print("Entities in '%s'" % test_text)
    for ent in doc.ents:
      print(ent)
# Out:
# Entities in 'Poco f3 ni?'
# Poco f3
# Entities in 'poco x3 Ata ki made by India.....'
# poco x3
# Entities in 'redmi Note 10 4/64'
# redmi Note
# Entities in 'waiting for iphone 12 pro max'
# iphone 12
# Entities in 'iphone x 5G version?'
# iphone x
# Entities in 'Poco x3 pro int. Global available? Price?'
# Poco x3
# Entities in 'oneplus 8 Official naki unofficial asbe....'
# oneplus 8
# Entities in 'R u bringing 4g or 5g iphone 12?'
# iphone 12
# Entities in 'Redmi note 9 pro max prise koto..'
# Redmi note
# Entities in 'poco x3 Price??'
# poco x3
# Entities in 'When come mi 11 and price'
# mi 11
# Entities in 'pixel 4 4G or 5G ? 5G hole amar ekta lagbei lagbe'
# pixel
# Entities in 'poco x3 ind (6/128gb) unofficial available??'
# poco x3
# Entities in 'Price 25k we niche house neya jai..'
# Entities in 'Price 53k er moddhe galaxy a5 pawa jabe ?'
# galaxy a5

# %%
pip install cupy
# Out:
# ...
#      |████████████████████████████████| 1.7 MB 847 kB/s eta 0:00:01
#     ERROR: Command errored out with exit status 1:
#      command: /opt/anaconda3/envs/tensorflow/bin/python -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'/private/var/folders/yw/9qy5zpfn2vd0dkj5f1t550w00000gn/T/pip-install-urda206m/cupy_4922f026e59445f1836454e14328ef7e/setup.py'"'"'; __file__='"'"'/private/var/folders/yw/9qy5zpfn2vd0dkj5f1t550w00000gn/T/pip-install-urda206m/cupy_4922f026e59445f1836454e14328ef7e/setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' egg_info --egg-base /private/var/folders/yw/9qy5zpfn2vd0dkj5f1t550w00000gn/T/pip-pip-egg-info-hj6xs9bl
# ...

# %%
import cupy
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-41-329ec5cf1bc8> in <module>
# ----> 1 import cupy
#
# ModuleNotFoundError: No module named 'cupy'
